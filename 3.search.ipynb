# %% [markdown]
# ## Searching for Similar Vectors and Filtering the results based on Payload fields
#
# ### Filtering Clauses
# 1. Must
# 2. Should
# 3. Must Not
#
# ### Filtering Conditions
#
# 1. Match
# 2. MatchAny
# 3. Match Except
# 4. Nested Key
# 5. Full text
# 6. Range
# 7. Geo
# 8. Is Empty / Is Null
# 9. Has ID

# %%
from qdrant_client import QdrantClient
from qdrant_client.http import models

# %%
client = QdrantClient("localhost", port=6333, timeout=300)
client.get_collections()
# Out:
# CollectionsResponse(collections=[CollectionDescription(name='multi_vector_collection'), CollectionDescription(name='wolt_food'), CollectionDescription(name='hello_world_collection')])

# %%
from random import  uniform

# Simple search
search_vec = [uniform(-0.999, 0.999) for x in range(512)]
client.search(
    collection_name="wolt_food",
    query_vector=( search_vec),
    limit=1,with_vectors=False
)
# Out:
# [ScoredPoint(id=253922, version=11907, score=0.12976074, payload={'cafe': {'address': 'Vinohradská 45', 'categories': ['doner', 'mediterranean', 'kebab', 'vegetarian', 'salad'], 'location': {'lat': 50.0775462, 'lon': 14.4400182}, 'menu_id': '619b989c0abfc11288092db5', 'name': 'Bukhara Kebab', 'rating': 8.4, 'slug': 'bukhara-kebab-vino'}, 'description': 'plast', 'image': 'https://wolt-menu-images-cdn.wolt.com/menu-images/619b989c0abfc11288092db5/73a4e6b2-ecaf-11ec-bf93-8e809beb5017_image.jpeg', 'image_file': '73a4e6b2-ecaf-11ec-bf93-8e809beb5017_image.jpeg', 'name': 'Ayran'}, vector=None, shard_key=None)]

# %%
# Search with filters

search_vec = [-0.027882958, 0.044092737, 0.0731473, 0.06553474, 0.024171988, 0.01697372, 0.0020604038, 0.018047482, -0.031200834, -0.014620315, -0.03596877, -0.008047461, 0.020798953, -0.014641951, 0.012549569, -0.029867202, 0.017640492, 0.020679252, 0.014639293, 0.02098035, -0.11850266, 0.008514167, -0.009126163, -0.03365829, -0.050205294, 0.017878275, -0.013079402, -0.03470298, 0.0053403503, -0.030538736, -0.00077569514, 0.046366554, 0.021818455, 0.048005834, 0.04522572, 0.013886643, -0.040764034, -0.019520732, -0.028808843, 0.07130225, -0.040791865, -0.010126803, -0.018052312, -0.002201882, -0.02058981, 0.03004692, -0.015570573, -0.00031868406, -0.0065039033, -0.045852456, 0.037677098, -0.007673897, 0.041015055, -0.0016164425, 0.008414605, 0.004175664, -0.050539035, -0.006734321, 0.08072506, -0.02726352, 0.03412241, -0.013328949, 0.0043830182, -0.020793792, -0.053872947, 0.012582162, 0.025352875, 0.05972377, -0.047683716, -0.040093377, -0.055419512, -0.0015524544, -0.06110616, 0.00039961239, 0.017122721, 0.011367437, 0.011612826, 0.017466443, 0.03495627, 0.037525106, 0.03702163, 0.029719371, 0.022293076, -0.103361145, -0.0051242076, -0.024882244, -0.0020247647, -0.034090083, -0.011648688, -0.0196668, 0.030498808, 0.049275327, -0.54135513, -0.0009911052, 0.05663518, 0.07849116, -0.026038505, -0.0178324, -0.035706922, -0.011421131, 0.0029203151, -0.051898856, -0.07163099, 0.023290059, -0.05910354, 0.035753418, -0.12370726, 0.00086394034, 0.062437817, 0.009168275, 0.003083251, 0.034232344, -0.02869723, -0.013457852, -0.011179466, 0.013072467, -0.003246991, -0.0380963, 0.027967058, -0.075501956, 0.0020709995, 0.009059259, 0.038587045, -0.00038104434, -0.0018610929, -0.009475333, -0.058327895, -0.0032828397, 0.004082257, -0.02602711, 0.014781226, -0.02390209, 0.0125596225, 0.08649576, 0.01703702, 0.03508497, 0.022272123, -0.04628153, -0.048454344, -0.0026485103, -0.03246412, 0.027184749, 0.009867273, 0.14205816, 0.0078798365, 0.02190687, -0.045301028, 0.040254034, -0.012405296, 0.02776755, -0.023437733, -0.010314621, 0.042177826, 0.031779177, -0.004419486, -0.04076263, -0.0052590473, 0.047290847, -0.03447568, -0.036947362, 0.031243473, -0.01243047, -0.007960975, -0.0105248885, 0.0032904854, -0.040179256, 0.022467114, -0.016306987, -0.014524242, 0.0072526056, -0.052280653, -0.012893598, -0.018354755, -0.039249703, 0.019507786, -0.03402438, -0.018815486, 0.037815843, 0.011572507, 0.01665657, 0.05349542, 0.06262594, -0.030739747, -0.01770206, -0.008022269, 0.044468857, 0.01187554, -0.03259911, -0.045163155, 0.005873695, -0.007031134, 0.038209956, 0.009773543, 0.018458132, 0.03298603, -0.04802215, -0.029331522, 0.009736381, 0.0014193252, -0.029266646, 0.023204679, 0.042884104, 0.036555525, 0.01989023, 0.020288104, -0.0019939796, 0.046266165, 0.009911118, -0.042073734, 0.0065396074, 0.065789275, 0.09641775, 0.017465355, 0.013128908, -0.03578239, 0.0231149, -0.021422157, -0.020437583, 0.025115158, 0.07037789, -0.0053526293, 0.0332623, -0.026476895, -0.03033616, -0.019557651, -0.03204936, 0.03887614, -0.027996426, 0.0013627007, 0.022591986, -0.049152315, -0.0028359122, -0.0057826117, 0.021139933, -0.05027323, 0.03936416, 0.04173886, -0.01125345, -0.023771996, 0.02028911, 0.0033836125, 0.031044248, 0.020033073, -0.027494857, -0.033545006, -0.058906768, 0.073347345, 0.062005993, 0.058484167, -0.00084693066, 0.005806394, 0.015744092, -0.03523072, 0.02922224, 0.0038474149, -0.0039008649, -0.015494569, -0.00070764316, -0.094965115, 0.015117273, 0.0043013617, 0.035153188, -0.061654534, 0.11085618, -0.07268279, -0.04717712, 0.032327536, -0.00704601, 0.037253235, 0.039828334, 0.00019132228, 0.028836014, -0.03307291, 0.050360598, 0.025420163, -0.015225513, -0.018811153, -0.022560537, -0.017732488, 0.020477327, 0.006707524, 0.058765963, -0.013588514, -0.020977682, 0.008896715, 0.04134574, -0.10698203, 0.004244291, -0.03720219, 0.0044170176, 0.041443963, 0.0027526275, -0.0021434748, -0.015335212, 0.0079962425, -0.02696693, -0.02288115, 0.031034293, 0.017682327, -0.05848914, -0.04479324, 0.011601903, 0.010388493, -0.017750131, -0.021489227, -0.0032729304, -0.010810562, 0.039271474, -0.005443907, -0.03595853, 0.0087571675, 0.05415203, 0.08646665, -0.013219114, 0.014869744, 0.0072967107, 0.025243847, 0.008245362, 0.018706806, -0.00870218, 0.016055388, 0.1125789, 0.007172758, -0.10118515, -0.06442794, 0.02315382, -0.06188186, -0.047224343, -0.0068433783, -0.018128177, -0.018271362, 0.02823152, 0.025293395, -0.0020494026, 0.0068809926, 0.017121902, 0.018439798, 0.03130178, -0.033437964, 0.039703637, -0.037016135, -0.037987944, 0.042977445, -0.012018748, 0.0035625743, -0.041630413, 0.017406989, -0.01154436, -0.004412928, 0.022141416, -0.0036727574, -0.008466987, 0.049739495, -0.06508093, -0.017235989, 0.02064509, 0.016321411, 0.02698845, 0.07759906, 0.017539669, -0.017168278, -0.0035778203, -0.0042685103, -0.026442358, 0.009349095, -0.029512957, -0.0065311617, -0.013559519, 0.0011971226, -0.009184269, -0.031676, -0.038088094, -0.016622547, 0.02486724, 0.032041576, -0.0055186623, 0.12189721, 0.043474462, -0.047649466, 0.027484516, -0.0035824412, -0.05383745, -0.008161388, -0.053657126, -0.0027364586, -0.00012998936, -0.022307076, -0.0486638, -0.028614787, -0.02132962, 0.0058860867, -0.06802224, 0.02570573, -0.034879185, 0.015381588, -0.047763627, -0.0032830043, -0.0015959376, -0.029630827, 0.038304392, -0.032076925, 0.021378756, -0.00052743126, -0.022812814, -0.025454491, -0.0023286757, 0.02404244, -0.0006882598, 0.0044533503, -0.0035739143, -0.06078285, -0.024933875, 0.030997192, 0.059662618, -0.054907784, 0.009324956, -0.007146112, 0.00516383, 0.030976022, -0.00035195865, -0.07011518, 0.06669572, -0.016511286, 0.031048367, 0.016499205, -0.02108085, -0.0045708157, -0.008500429, -0.25783044, 0.041272227, -0.0057234215, 0.016666386, 0.06816838, -0.009868127, 0.014825844, -0.022925615, -0.008001345, 0.046653997, -0.00014183977, -0.0026383696, -0.03135771, -0.030197483, 0.03716319, 0.0051222467, 0.033846315, -0.039608024, -0.029459938, 0.014192158, 0.015020755, -0.059405386, 0.044410657, 0.0031503357, -0.030107027, -0.032072756, -0.014434276, 0.017240832, 0.012384157, 0.027699955, 0.015897155, -0.017908351, 0.044406805, -0.06329205, 0.035939753, 0.024845755, 0.03015499, -0.0450442, -0.030212563, -0.04875517, -0.02823563, 0.05420893, 0.031548176, -0.0060583507, -0.017916419, -0.04930094, 0.020581705, -0.020350741, -0.020912305, -0.026117438, -0.04963092, -0.025120517, 0.002230628, 0.011512409, -0.023473363, -0.04301427, 0.018177832, 0.010988586, 0.027035486, 0.043955598, 0.019385587, -0.039110214, 0.07951547, 0.03305704, -0.022609217, -0.033687174, -0.032354735, -0.025954131, -0.01293125, 0.019692834, 0.00054087455, -0.03605654, 0.018381594, 0.0050960053, 0.011778557, 0.054119013, -0.018572157, 0.020884385, -0.030553969, 0.0099051595, 0.008738324, 0.03167156, -0.019423256, -0.025590187]
client.search(
    collection_name="wolt_food",
    query_vector=( search_vec),
    limit=3,
    query_filter=models.Filter(
    must=[
        models.FieldCondition(
            key="name",
            match=models.MatchValue(
                value="Ayran",
            ),
        ),
        models.FieldCondition(
            key="description",
            match=models.MatchValue(
                value="",
            ),
        )
    ]
),
)
# Out:
# [ScoredPoint(id=1451234, version=68032, score=1.0183411, payload={'cafe': {'address': 'Skt. Pauls Kirkeplads 19 st tv', 'categories': ['pizza', 'italian'], 'location': {'lat': 56.14561089999999, 'lon': 10.2045166}, 'menu_id': '60a62b0d52d7b5c7d527562b', 'name': 'Amigo Pizza og Grill', 'rating': 8.2, 'slug': 'amigo-pizza-og-grill'}, 'description': '', 'image': 'https://wolt-menu-images-cdn.wolt.com/menu-images/60a62b0d52d7b5c7d527562b/26445192-ff5b-11eb-bcc9-0ae0c111c25d_wolt_21.08.12_amigo_pizza1209.jpeg', 'image_file': '26445192-ff5b-11eb-bcc9-0ae0c111c25d_wolt_21.08.12_amigo_pizza1209.jpeg', 'name': 'Ayran'}, vector=None, shard_key=None),
# ...

# %%
# Search filter clause - should
search_vec = [-0.027882958, 0.044092737, 0.0731473, 0.06553474, 0.024171988, 0.01697372, 0.0020604038, 0.018047482, -0.031200834, -0.014620315, -0.03596877, -0.008047461, 0.020798953, -0.014641951, 0.012549569, -0.029867202, 0.017640492, 0.020679252, 0.014639293, 0.02098035, -0.11850266, 0.008514167, -0.009126163, -0.03365829, -0.050205294, 0.017878275, -0.013079402, -0.03470298, 0.0053403503, -0.030538736, -0.00077569514, 0.046366554, 0.021818455, 0.048005834, 0.04522572, 0.013886643, -0.040764034, -0.019520732, -0.028808843, 0.07130225, -0.040791865, -0.010126803, -0.018052312, -0.002201882, -0.02058981, 0.03004692, -0.015570573, -0.00031868406, -0.0065039033, -0.045852456, 0.037677098, -0.007673897, 0.041015055, -0.0016164425, 0.008414605, 0.004175664, -0.050539035, -0.006734321, 0.08072506, -0.02726352, 0.03412241, -0.013328949, 0.0043830182, -0.020793792, -0.053872947, 0.012582162, 0.025352875, 0.05972377, -0.047683716, -0.040093377, -0.055419512, -0.0015524544, -0.06110616, 0.00039961239, 0.017122721, 0.011367437, 0.011612826, 0.017466443, 0.03495627, 0.037525106, 0.03702163, 0.029719371, 0.022293076, -0.103361145, -0.0051242076, -0.024882244, -0.0020247647, -0.034090083, -0.011648688, -0.0196668, 0.030498808, 0.049275327, -0.54135513, -0.0009911052, 0.05663518, 0.07849116, -0.026038505, -0.0178324, -0.035706922, -0.011421131, 0.0029203151, -0.051898856, -0.07163099, 0.023290059, -0.05910354, 0.035753418, -0.12370726, 0.00086394034, 0.062437817, 0.009168275, 0.003083251, 0.034232344, -0.02869723, -0.013457852, -0.011179466, 0.013072467, -0.003246991, -0.0380963, 0.027967058, -0.075501956, 0.0020709995, 0.009059259, 0.038587045, -0.00038104434, -0.0018610929, -0.009475333, -0.058327895, -0.0032828397, 0.004082257, -0.02602711, 0.014781226, -0.02390209, 0.0125596225, 0.08649576, 0.01703702, 0.03508497, 0.022272123, -0.04628153, -0.048454344, -0.0026485103, -0.03246412, 0.027184749, 0.009867273, 0.14205816, 0.0078798365, 0.02190687, -0.045301028, 0.040254034, -0.012405296, 0.02776755, -0.023437733, -0.010314621, 0.042177826, 0.031779177, -0.004419486, -0.04076263, -0.0052590473, 0.047290847, -0.03447568, -0.036947362, 0.031243473, -0.01243047, -0.007960975, -0.0105248885, 0.0032904854, -0.040179256, 0.022467114, -0.016306987, -0.014524242, 0.0072526056, -0.052280653, -0.012893598, -0.018354755, -0.039249703, 0.019507786, -0.03402438, -0.018815486, 0.037815843, 0.011572507, 0.01665657, 0.05349542, 0.06262594, -0.030739747, -0.01770206, -0.008022269, 0.044468857, 0.01187554, -0.03259911, -0.045163155, 0.005873695, -0.007031134, 0.038209956, 0.009773543, 0.018458132, 0.03298603, -0.04802215, -0.029331522, 0.009736381, 0.0014193252, -0.029266646, 0.023204679, 0.042884104, 0.036555525, 0.01989023, 0.020288104, -0.0019939796, 0.046266165, 0.009911118, -0.042073734, 0.0065396074, 0.065789275, 0.09641775, 0.017465355, 0.013128908, -0.03578239, 0.0231149, -0.021422157, -0.020437583, 0.025115158, 0.07037789, -0.0053526293, 0.0332623, -0.026476895, -0.03033616, -0.019557651, -0.03204936, 0.03887614, -0.027996426, 0.0013627007, 0.022591986, -0.049152315, -0.0028359122, -0.0057826117, 0.021139933, -0.05027323, 0.03936416, 0.04173886, -0.01125345, -0.023771996, 0.02028911, 0.0033836125, 0.031044248, 0.020033073, -0.027494857, -0.033545006, -0.058906768, 0.073347345, 0.062005993, 0.058484167, -0.00084693066, 0.005806394, 0.015744092, -0.03523072, 0.02922224, 0.0038474149, -0.0039008649, -0.015494569, -0.00070764316, -0.094965115, 0.015117273, 0.0043013617, 0.035153188, -0.061654534, 0.11085618, -0.07268279, -0.04717712, 0.032327536, -0.00704601, 0.037253235, 0.039828334, 0.00019132228, 0.028836014, -0.03307291, 0.050360598, 0.025420163, -0.015225513, -0.018811153, -0.022560537, -0.017732488, 0.020477327, 0.006707524, 0.058765963, -0.013588514, -0.020977682, 0.008896715, 0.04134574, -0.10698203, 0.004244291, -0.03720219, 0.0044170176, 0.041443963, 0.0027526275, -0.0021434748, -0.015335212, 0.0079962425, -0.02696693, -0.02288115, 0.031034293, 0.017682327, -0.05848914, -0.04479324, 0.011601903, 0.010388493, -0.017750131, -0.021489227, -0.0032729304, -0.010810562, 0.039271474, -0.005443907, -0.03595853, 0.0087571675, 0.05415203, 0.08646665, -0.013219114, 0.014869744, 0.0072967107, 0.025243847, 0.008245362, 0.018706806, -0.00870218, 0.016055388, 0.1125789, 0.007172758, -0.10118515, -0.06442794, 0.02315382, -0.06188186, -0.047224343, -0.0068433783, -0.018128177, -0.018271362, 0.02823152, 0.025293395, -0.0020494026, 0.0068809926, 0.017121902, 0.018439798, 0.03130178, -0.033437964, 0.039703637, -0.037016135, -0.037987944, 0.042977445, -0.012018748, 0.0035625743, -0.041630413, 0.017406989, -0.01154436, -0.004412928, 0.022141416, -0.0036727574, -0.008466987, 0.049739495, -0.06508093, -0.017235989, 0.02064509, 0.016321411, 0.02698845, 0.07759906, 0.017539669, -0.017168278, -0.0035778203, -0.0042685103, -0.026442358, 0.009349095, -0.029512957, -0.0065311617, -0.013559519, 0.0011971226, -0.009184269, -0.031676, -0.038088094, -0.016622547, 0.02486724, 0.032041576, -0.0055186623, 0.12189721, 0.043474462, -0.047649466, 0.027484516, -0.0035824412, -0.05383745, -0.008161388, -0.053657126, -0.0027364586, -0.00012998936, -0.022307076, -0.0486638, -0.028614787, -0.02132962, 0.0058860867, -0.06802224, 0.02570573, -0.034879185, 0.015381588, -0.047763627, -0.0032830043, -0.0015959376, -0.029630827, 0.038304392, -0.032076925, 0.021378756, -0.00052743126, -0.022812814, -0.025454491, -0.0023286757, 0.02404244, -0.0006882598, 0.0044533503, -0.0035739143, -0.06078285, -0.024933875, 0.030997192, 0.059662618, -0.054907784, 0.009324956, -0.007146112, 0.00516383, 0.030976022, -0.00035195865, -0.07011518, 0.06669572, -0.016511286, 0.031048367, 0.016499205, -0.02108085, -0.0045708157, -0.008500429, -0.25783044, 0.041272227, -0.0057234215, 0.016666386, 0.06816838, -0.009868127, 0.014825844, -0.022925615, -0.008001345, 0.046653997, -0.00014183977, -0.0026383696, -0.03135771, -0.030197483, 0.03716319, 0.0051222467, 0.033846315, -0.039608024, -0.029459938, 0.014192158, 0.015020755, -0.059405386, 0.044410657, 0.0031503357, -0.030107027, -0.032072756, -0.014434276, 0.017240832, 0.012384157, 0.027699955, 0.015897155, -0.017908351, 0.044406805, -0.06329205, 0.035939753, 0.024845755, 0.03015499, -0.0450442, -0.030212563, -0.04875517, -0.02823563, 0.05420893, 0.031548176, -0.0060583507, -0.017916419, -0.04930094, 0.020581705, -0.020350741, -0.020912305, -0.026117438, -0.04963092, -0.025120517, 0.002230628, 0.011512409, -0.023473363, -0.04301427, 0.018177832, 0.010988586, 0.027035486, 0.043955598, 0.019385587, -0.039110214, 0.07951547, 0.03305704, -0.022609217, -0.033687174, -0.032354735, -0.025954131, -0.01293125, 0.019692834, 0.00054087455, -0.03605654, 0.018381594, 0.0050960053, 0.011778557, 0.054119013, -0.018572157, 0.020884385, -0.030553969, 0.0099051595, 0.008738324, 0.03167156, -0.019423256, -0.025590187]
client.search(
    collection_name="wolt_food",
    query_vector=( search_vec),
    limit=3,
    query_filter=models.Filter(
    should=[
        models.FieldCondition(
            key="name",
            match=models.MatchValue(
                value="Ayran",
            ),
        ),
        models.FieldCondition(
            key="description",
            match=models.MatchValue(
                value="Hello",
            ),
        )
    ]
),
)
# Out:
# [ScoredPoint(id=1451234, version=68032, score=1.0183411, payload={'cafe': {'address': 'Skt. Pauls Kirkeplads 19 st tv', 'categories': ['pizza', 'italian'], 'location': {'lat': 56.14561089999999, 'lon': 10.2045166}, 'menu_id': '60a62b0d52d7b5c7d527562b', 'name': 'Amigo Pizza og Grill', 'rating': 8.2, 'slug': 'amigo-pizza-og-grill'}, 'description': '', 'image': 'https://wolt-menu-images-cdn.wolt.com/menu-images/60a62b0d52d7b5c7d527562b/26445192-ff5b-11eb-bcc9-0ae0c111c25d_wolt_21.08.12_amigo_pizza1209.jpeg', 'image_file': '26445192-ff5b-11eb-bcc9-0ae0c111c25d_wolt_21.08.12_amigo_pizza1209.jpeg', 'name': 'Ayran'}, vector=None, shard_key=None),
# ...

# %%
# Search filter clause - mustnot

search_vec = [-0.027882958, 0.044092737, 0.0731473, 0.06553474, 0.024171988, 0.01697372, 0.0020604038, 0.018047482, -0.031200834, -0.014620315, -0.03596877, -0.008047461, 0.020798953, -0.014641951, 0.012549569, -0.029867202, 0.017640492, 0.020679252, 0.014639293, 0.02098035, -0.11850266, 0.008514167, -0.009126163, -0.03365829, -0.050205294, 0.017878275, -0.013079402, -0.03470298, 0.0053403503, -0.030538736, -0.00077569514, 0.046366554, 0.021818455, 0.048005834, 0.04522572, 0.013886643, -0.040764034, -0.019520732, -0.028808843, 0.07130225, -0.040791865, -0.010126803, -0.018052312, -0.002201882, -0.02058981, 0.03004692, -0.015570573, -0.00031868406, -0.0065039033, -0.045852456, 0.037677098, -0.007673897, 0.041015055, -0.0016164425, 0.008414605, 0.004175664, -0.050539035, -0.006734321, 0.08072506, -0.02726352, 0.03412241, -0.013328949, 0.0043830182, -0.020793792, -0.053872947, 0.012582162, 0.025352875, 0.05972377, -0.047683716, -0.040093377, -0.055419512, -0.0015524544, -0.06110616, 0.00039961239, 0.017122721, 0.011367437, 0.011612826, 0.017466443, 0.03495627, 0.037525106, 0.03702163, 0.029719371, 0.022293076, -0.103361145, -0.0051242076, -0.024882244, -0.0020247647, -0.034090083, -0.011648688, -0.0196668, 0.030498808, 0.049275327, -0.54135513, -0.0009911052, 0.05663518, 0.07849116, -0.026038505, -0.0178324, -0.035706922, -0.011421131, 0.0029203151, -0.051898856, -0.07163099, 0.023290059, -0.05910354, 0.035753418, -0.12370726, 0.00086394034, 0.062437817, 0.009168275, 0.003083251, 0.034232344, -0.02869723, -0.013457852, -0.011179466, 0.013072467, -0.003246991, -0.0380963, 0.027967058, -0.075501956, 0.0020709995, 0.009059259, 0.038587045, -0.00038104434, -0.0018610929, -0.009475333, -0.058327895, -0.0032828397, 0.004082257, -0.02602711, 0.014781226, -0.02390209, 0.0125596225, 0.08649576, 0.01703702, 0.03508497, 0.022272123, -0.04628153, -0.048454344, -0.0026485103, -0.03246412, 0.027184749, 0.009867273, 0.14205816, 0.0078798365, 0.02190687, -0.045301028, 0.040254034, -0.012405296, 0.02776755, -0.023437733, -0.010314621, 0.042177826, 0.031779177, -0.004419486, -0.04076263, -0.0052590473, 0.047290847, -0.03447568, -0.036947362, 0.031243473, -0.01243047, -0.007960975, -0.0105248885, 0.0032904854, -0.040179256, 0.022467114, -0.016306987, -0.014524242, 0.0072526056, -0.052280653, -0.012893598, -0.018354755, -0.039249703, 0.019507786, -0.03402438, -0.018815486, 0.037815843, 0.011572507, 0.01665657, 0.05349542, 0.06262594, -0.030739747, -0.01770206, -0.008022269, 0.044468857, 0.01187554, -0.03259911, -0.045163155, 0.005873695, -0.007031134, 0.038209956, 0.009773543, 0.018458132, 0.03298603, -0.04802215, -0.029331522, 0.009736381, 0.0014193252, -0.029266646, 0.023204679, 0.042884104, 0.036555525, 0.01989023, 0.020288104, -0.0019939796, 0.046266165, 0.009911118, -0.042073734, 0.0065396074, 0.065789275, 0.09641775, 0.017465355, 0.013128908, -0.03578239, 0.0231149, -0.021422157, -0.020437583, 0.025115158, 0.07037789, -0.0053526293, 0.0332623, -0.026476895, -0.03033616, -0.019557651, -0.03204936, 0.03887614, -0.027996426, 0.0013627007, 0.022591986, -0.049152315, -0.0028359122, -0.0057826117, 0.021139933, -0.05027323, 0.03936416, 0.04173886, -0.01125345, -0.023771996, 0.02028911, 0.0033836125, 0.031044248, 0.020033073, -0.027494857, -0.033545006, -0.058906768, 0.073347345, 0.062005993, 0.058484167, -0.00084693066, 0.005806394, 0.015744092, -0.03523072, 0.02922224, 0.0038474149, -0.0039008649, -0.015494569, -0.00070764316, -0.094965115, 0.015117273, 0.0043013617, 0.035153188, -0.061654534, 0.11085618, -0.07268279, -0.04717712, 0.032327536, -0.00704601, 0.037253235, 0.039828334, 0.00019132228, 0.028836014, -0.03307291, 0.050360598, 0.025420163, -0.015225513, -0.018811153, -0.022560537, -0.017732488, 0.020477327, 0.006707524, 0.058765963, -0.013588514, -0.020977682, 0.008896715, 0.04134574, -0.10698203, 0.004244291, -0.03720219, 0.0044170176, 0.041443963, 0.0027526275, -0.0021434748, -0.015335212, 0.0079962425, -0.02696693, -0.02288115, 0.031034293, 0.017682327, -0.05848914, -0.04479324, 0.011601903, 0.010388493, -0.017750131, -0.021489227, -0.0032729304, -0.010810562, 0.039271474, -0.005443907, -0.03595853, 0.0087571675, 0.05415203, 0.08646665, -0.013219114, 0.014869744, 0.0072967107, 0.025243847, 0.008245362, 0.018706806, -0.00870218, 0.016055388, 0.1125789, 0.007172758, -0.10118515, -0.06442794, 0.02315382, -0.06188186, -0.047224343, -0.0068433783, -0.018128177, -0.018271362, 0.02823152, 0.025293395, -0.0020494026, 0.0068809926, 0.017121902, 0.018439798, 0.03130178, -0.033437964, 0.039703637, -0.037016135, -0.037987944, 0.042977445, -0.012018748, 0.0035625743, -0.041630413, 0.017406989, -0.01154436, -0.004412928, 0.022141416, -0.0036727574, -0.008466987, 0.049739495, -0.06508093, -0.017235989, 0.02064509, 0.016321411, 0.02698845, 0.07759906, 0.017539669, -0.017168278, -0.0035778203, -0.0042685103, -0.026442358, 0.009349095, -0.029512957, -0.0065311617, -0.013559519, 0.0011971226, -0.009184269, -0.031676, -0.038088094, -0.016622547, 0.02486724, 0.032041576, -0.0055186623, 0.12189721, 0.043474462, -0.047649466, 0.027484516, -0.0035824412, -0.05383745, -0.008161388, -0.053657126, -0.0027364586, -0.00012998936, -0.022307076, -0.0486638, -0.028614787, -0.02132962, 0.0058860867, -0.06802224, 0.02570573, -0.034879185, 0.015381588, -0.047763627, -0.0032830043, -0.0015959376, -0.029630827, 0.038304392, -0.032076925, 0.021378756, -0.00052743126, -0.022812814, -0.025454491, -0.0023286757, 0.02404244, -0.0006882598, 0.0044533503, -0.0035739143, -0.06078285, -0.024933875, 0.030997192, 0.059662618, -0.054907784, 0.009324956, -0.007146112, 0.00516383, 0.030976022, -0.00035195865, -0.07011518, 0.06669572, -0.016511286, 0.031048367, 0.016499205, -0.02108085, -0.0045708157, -0.008500429, -0.25783044, 0.041272227, -0.0057234215, 0.016666386, 0.06816838, -0.009868127, 0.014825844, -0.022925615, -0.008001345, 0.046653997, -0.00014183977, -0.0026383696, -0.03135771, -0.030197483, 0.03716319, 0.0051222467, 0.033846315, -0.039608024, -0.029459938, 0.014192158, 0.015020755, -0.059405386, 0.044410657, 0.0031503357, -0.030107027, -0.032072756, -0.014434276, 0.017240832, 0.012384157, 0.027699955, 0.015897155, -0.017908351, 0.044406805, -0.06329205, 0.035939753, 0.024845755, 0.03015499, -0.0450442, -0.030212563, -0.04875517, -0.02823563, 0.05420893, 0.031548176, -0.0060583507, -0.017916419, -0.04930094, 0.020581705, -0.020350741, -0.020912305, -0.026117438, -0.04963092, -0.025120517, 0.002230628, 0.011512409, -0.023473363, -0.04301427, 0.018177832, 0.010988586, 0.027035486, 0.043955598, 0.019385587, -0.039110214, 0.07951547, 0.03305704, -0.022609217, -0.033687174, -0.032354735, -0.025954131, -0.01293125, 0.019692834, 0.00054087455, -0.03605654, 0.018381594, 0.0050960053, 0.011778557, 0.054119013, -0.018572157, 0.020884385, -0.030553969, 0.0099051595, 0.008738324, 0.03167156, -0.019423256, -0.025590187]
client.search(
    collection_name="wolt_food",
    query_vector=( search_vec),
    limit=3,
    query_filter=models.Filter(
    must_not=[
        models.FieldCondition(
            key="name",
            match=models.MatchValue(
                value="Ayran",
            ),
        ),
        models.FieldCondition(
            key="description",
            match=models.MatchValue(
                value="Hello",
            ),
        )
    ]
),
)
# Out:
# [ScoredPoint(id=965826, version=45279, score=0.84921265, payload={'cafe': {'address': 'Italská 4', 'categories': ['burgers', 'dessert', 'steak', 'kebab', 'meat-fish', 'pizza', 'salad', 'turkish', 'halal'], 'location': {'lat': 50.0763128, 'lon': 14.435342}, 'menu_id': '5f17fba60e59360fa003f755', 'name': 'Pasha Kebab Bistro \n', 'rating': 9.4, 'slug': 'pasha-kebab-bistro-italska'}, 'description': 'jogurtový nápoj', 'image': 'https://wolt-menu-images-cdn.wolt.com/menu-images/5f17fba60e59360fa003f755/09b5abae-2cf0-11eb-b0fb-aea8b89b8bf3_img_8177.jpeg', 'image_file': '09b5abae-2cf0-11eb-b0fb-aea8b89b8bf3_img_8177.jpeg', 'name': 'AYRAN'}, vector=None, shard_key=None),
# ...

# %%
# Search filter clause - mixing multiple clauses

search_vec = [-0.027882958, 0.044092737, 0.0731473, 0.06553474, 0.024171988, 0.01697372, 0.0020604038, 0.018047482, -0.031200834, -0.014620315, -0.03596877, -0.008047461, 0.020798953, -0.014641951, 0.012549569, -0.029867202, 0.017640492, 0.020679252, 0.014639293, 0.02098035, -0.11850266, 0.008514167, -0.009126163, -0.03365829, -0.050205294, 0.017878275, -0.013079402, -0.03470298, 0.0053403503, -0.030538736, -0.00077569514, 0.046366554, 0.021818455, 0.048005834, 0.04522572, 0.013886643, -0.040764034, -0.019520732, -0.028808843, 0.07130225, -0.040791865, -0.010126803, -0.018052312, -0.002201882, -0.02058981, 0.03004692, -0.015570573, -0.00031868406, -0.0065039033, -0.045852456, 0.037677098, -0.007673897, 0.041015055, -0.0016164425, 0.008414605, 0.004175664, -0.050539035, -0.006734321, 0.08072506, -0.02726352, 0.03412241, -0.013328949, 0.0043830182, -0.020793792, -0.053872947, 0.012582162, 0.025352875, 0.05972377, -0.047683716, -0.040093377, -0.055419512, -0.0015524544, -0.06110616, 0.00039961239, 0.017122721, 0.011367437, 0.011612826, 0.017466443, 0.03495627, 0.037525106, 0.03702163, 0.029719371, 0.022293076, -0.103361145, -0.0051242076, -0.024882244, -0.0020247647, -0.034090083, -0.011648688, -0.0196668, 0.030498808, 0.049275327, -0.54135513, -0.0009911052, 0.05663518, 0.07849116, -0.026038505, -0.0178324, -0.035706922, -0.011421131, 0.0029203151, -0.051898856, -0.07163099, 0.023290059, -0.05910354, 0.035753418, -0.12370726, 0.00086394034, 0.062437817, 0.009168275, 0.003083251, 0.034232344, -0.02869723, -0.013457852, -0.011179466, 0.013072467, -0.003246991, -0.0380963, 0.027967058, -0.075501956, 0.0020709995, 0.009059259, 0.038587045, -0.00038104434, -0.0018610929, -0.009475333, -0.058327895, -0.0032828397, 0.004082257, -0.02602711, 0.014781226, -0.02390209, 0.0125596225, 0.08649576, 0.01703702, 0.03508497, 0.022272123, -0.04628153, -0.048454344, -0.0026485103, -0.03246412, 0.027184749, 0.009867273, 0.14205816, 0.0078798365, 0.02190687, -0.045301028, 0.040254034, -0.012405296, 0.02776755, -0.023437733, -0.010314621, 0.042177826, 0.031779177, -0.004419486, -0.04076263, -0.0052590473, 0.047290847, -0.03447568, -0.036947362, 0.031243473, -0.01243047, -0.007960975, -0.0105248885, 0.0032904854, -0.040179256, 0.022467114, -0.016306987, -0.014524242, 0.0072526056, -0.052280653, -0.012893598, -0.018354755, -0.039249703, 0.019507786, -0.03402438, -0.018815486, 0.037815843, 0.011572507, 0.01665657, 0.05349542, 0.06262594, -0.030739747, -0.01770206, -0.008022269, 0.044468857, 0.01187554, -0.03259911, -0.045163155, 0.005873695, -0.007031134, 0.038209956, 0.009773543, 0.018458132, 0.03298603, -0.04802215, -0.029331522, 0.009736381, 0.0014193252, -0.029266646, 0.023204679, 0.042884104, 0.036555525, 0.01989023, 0.020288104, -0.0019939796, 0.046266165, 0.009911118, -0.042073734, 0.0065396074, 0.065789275, 0.09641775, 0.017465355, 0.013128908, -0.03578239, 0.0231149, -0.021422157, -0.020437583, 0.025115158, 0.07037789, -0.0053526293, 0.0332623, -0.026476895, -0.03033616, -0.019557651, -0.03204936, 0.03887614, -0.027996426, 0.0013627007, 0.022591986, -0.049152315, -0.0028359122, -0.0057826117, 0.021139933, -0.05027323, 0.03936416, 0.04173886, -0.01125345, -0.023771996, 0.02028911, 0.0033836125, 0.031044248, 0.020033073, -0.027494857, -0.033545006, -0.058906768, 0.073347345, 0.062005993, 0.058484167, -0.00084693066, 0.005806394, 0.015744092, -0.03523072, 0.02922224, 0.0038474149, -0.0039008649, -0.015494569, -0.00070764316, -0.094965115, 0.015117273, 0.0043013617, 0.035153188, -0.061654534, 0.11085618, -0.07268279, -0.04717712, 0.032327536, -0.00704601, 0.037253235, 0.039828334, 0.00019132228, 0.028836014, -0.03307291, 0.050360598, 0.025420163, -0.015225513, -0.018811153, -0.022560537, -0.017732488, 0.020477327, 0.006707524, 0.058765963, -0.013588514, -0.020977682, 0.008896715, 0.04134574, -0.10698203, 0.004244291, -0.03720219, 0.0044170176, 0.041443963, 0.0027526275, -0.0021434748, -0.015335212, 0.0079962425, -0.02696693, -0.02288115, 0.031034293, 0.017682327, -0.05848914, -0.04479324, 0.011601903, 0.010388493, -0.017750131, -0.021489227, -0.0032729304, -0.010810562, 0.039271474, -0.005443907, -0.03595853, 0.0087571675, 0.05415203, 0.08646665, -0.013219114, 0.014869744, 0.0072967107, 0.025243847, 0.008245362, 0.018706806, -0.00870218, 0.016055388, 0.1125789, 0.007172758, -0.10118515, -0.06442794, 0.02315382, -0.06188186, -0.047224343, -0.0068433783, -0.018128177, -0.018271362, 0.02823152, 0.025293395, -0.0020494026, 0.0068809926, 0.017121902, 0.018439798, 0.03130178, -0.033437964, 0.039703637, -0.037016135, -0.037987944, 0.042977445, -0.012018748, 0.0035625743, -0.041630413, 0.017406989, -0.01154436, -0.004412928, 0.022141416, -0.0036727574, -0.008466987, 0.049739495, -0.06508093, -0.017235989, 0.02064509, 0.016321411, 0.02698845, 0.07759906, 0.017539669, -0.017168278, -0.0035778203, -0.0042685103, -0.026442358, 0.009349095, -0.029512957, -0.0065311617, -0.013559519, 0.0011971226, -0.009184269, -0.031676, -0.038088094, -0.016622547, 0.02486724, 0.032041576, -0.0055186623, 0.12189721, 0.043474462, -0.047649466, 0.027484516, -0.0035824412, -0.05383745, -0.008161388, -0.053657126, -0.0027364586, -0.00012998936, -0.022307076, -0.0486638, -0.028614787, -0.02132962, 0.0058860867, -0.06802224, 0.02570573, -0.034879185, 0.015381588, -0.047763627, -0.0032830043, -0.0015959376, -0.029630827, 0.038304392, -0.032076925, 0.021378756, -0.00052743126, -0.022812814, -0.025454491, -0.0023286757, 0.02404244, -0.0006882598, 0.0044533503, -0.0035739143, -0.06078285, -0.024933875, 0.030997192, 0.059662618, -0.054907784, 0.009324956, -0.007146112, 0.00516383, 0.030976022, -0.00035195865, -0.07011518, 0.06669572, -0.016511286, 0.031048367, 0.016499205, -0.02108085, -0.0045708157, -0.008500429, -0.25783044, 0.041272227, -0.0057234215, 0.016666386, 0.06816838, -0.009868127, 0.014825844, -0.022925615, -0.008001345, 0.046653997, -0.00014183977, -0.0026383696, -0.03135771, -0.030197483, 0.03716319, 0.0051222467, 0.033846315, -0.039608024, -0.029459938, 0.014192158, 0.015020755, -0.059405386, 0.044410657, 0.0031503357, -0.030107027, -0.032072756, -0.014434276, 0.017240832, 0.012384157, 0.027699955, 0.015897155, -0.017908351, 0.044406805, -0.06329205, 0.035939753, 0.024845755, 0.03015499, -0.0450442, -0.030212563, -0.04875517, -0.02823563, 0.05420893, 0.031548176, -0.0060583507, -0.017916419, -0.04930094, 0.020581705, -0.020350741, -0.020912305, -0.026117438, -0.04963092, -0.025120517, 0.002230628, 0.011512409, -0.023473363, -0.04301427, 0.018177832, 0.010988586, 0.027035486, 0.043955598, 0.019385587, -0.039110214, 0.07951547, 0.03305704, -0.022609217, -0.033687174, -0.032354735, -0.025954131, -0.01293125, 0.019692834, 0.00054087455, -0.03605654, 0.018381594, 0.0050960053, 0.011778557, 0.054119013, -0.018572157, 0.020884385, -0.030553969, 0.0099051595, 0.008738324, 0.03167156, -0.019423256, -0.025590187]
client.search(
    collection_name="wolt_food",
    query_vector=( search_vec),
    limit=3,
    query_filter=models.Filter(
    must=[
        models.FieldCondition(
            key="name",
            match=models.MatchValue(
                value="Ayran",
            ),
        )],
        must_not=[
        models.FieldCondition(
            key="description",
            match=models.MatchValue(
                value="Hello",
            ),
        )
    ]
),
)
# Out:
# [ScoredPoint(id=1451234, version=68032, score=1.0183411, payload={'cafe': {'address': 'Skt. Pauls Kirkeplads 19 st tv', 'categories': ['pizza', 'italian'], 'location': {'lat': 56.14561089999999, 'lon': 10.2045166}, 'menu_id': '60a62b0d52d7b5c7d527562b', 'name': 'Amigo Pizza og Grill', 'rating': 8.2, 'slug': 'amigo-pizza-og-grill'}, 'description': '', 'image': 'https://wolt-menu-images-cdn.wolt.com/menu-images/60a62b0d52d7b5c7d527562b/26445192-ff5b-11eb-bcc9-0ae0c111c25d_wolt_21.08.12_amigo_pizza1209.jpeg', 'image_file': '26445192-ff5b-11eb-bcc9-0ae0c111c25d_wolt_21.08.12_amigo_pizza1209.jpeg', 'name': 'Ayran'}, vector=None, shard_key=None),
# ...

# %%
# Search with filters - filtering conditions - match any

search_vec = [-0.027882958, 0.044092737, 0.0731473, 0.06553474, 0.024171988, 0.01697372, 0.0020604038, 0.018047482, -0.031200834, -0.014620315, -0.03596877, -0.008047461, 0.020798953, -0.014641951, 0.012549569, -0.029867202, 0.017640492, 0.020679252, 0.014639293, 0.02098035, -0.11850266, 0.008514167, -0.009126163, -0.03365829, -0.050205294, 0.017878275, -0.013079402, -0.03470298, 0.0053403503, -0.030538736, -0.00077569514, 0.046366554, 0.021818455, 0.048005834, 0.04522572, 0.013886643, -0.040764034, -0.019520732, -0.028808843, 0.07130225, -0.040791865, -0.010126803, -0.018052312, -0.002201882, -0.02058981, 0.03004692, -0.015570573, -0.00031868406, -0.0065039033, -0.045852456, 0.037677098, -0.007673897, 0.041015055, -0.0016164425, 0.008414605, 0.004175664, -0.050539035, -0.006734321, 0.08072506, -0.02726352, 0.03412241, -0.013328949, 0.0043830182, -0.020793792, -0.053872947, 0.012582162, 0.025352875, 0.05972377, -0.047683716, -0.040093377, -0.055419512, -0.0015524544, -0.06110616, 0.00039961239, 0.017122721, 0.011367437, 0.011612826, 0.017466443, 0.03495627, 0.037525106, 0.03702163, 0.029719371, 0.022293076, -0.103361145, -0.0051242076, -0.024882244, -0.0020247647, -0.034090083, -0.011648688, -0.0196668, 0.030498808, 0.049275327, -0.54135513, -0.0009911052, 0.05663518, 0.07849116, -0.026038505, -0.0178324, -0.035706922, -0.011421131, 0.0029203151, -0.051898856, -0.07163099, 0.023290059, -0.05910354, 0.035753418, -0.12370726, 0.00086394034, 0.062437817, 0.009168275, 0.003083251, 0.034232344, -0.02869723, -0.013457852, -0.011179466, 0.013072467, -0.003246991, -0.0380963, 0.027967058, -0.075501956, 0.0020709995, 0.009059259, 0.038587045, -0.00038104434, -0.0018610929, -0.009475333, -0.058327895, -0.0032828397, 0.004082257, -0.02602711, 0.014781226, -0.02390209, 0.0125596225, 0.08649576, 0.01703702, 0.03508497, 0.022272123, -0.04628153, -0.048454344, -0.0026485103, -0.03246412, 0.027184749, 0.009867273, 0.14205816, 0.0078798365, 0.02190687, -0.045301028, 0.040254034, -0.012405296, 0.02776755, -0.023437733, -0.010314621, 0.042177826, 0.031779177, -0.004419486, -0.04076263, -0.0052590473, 0.047290847, -0.03447568, -0.036947362, 0.031243473, -0.01243047, -0.007960975, -0.0105248885, 0.0032904854, -0.040179256, 0.022467114, -0.016306987, -0.014524242, 0.0072526056, -0.052280653, -0.012893598, -0.018354755, -0.039249703, 0.019507786, -0.03402438, -0.018815486, 0.037815843, 0.011572507, 0.01665657, 0.05349542, 0.06262594, -0.030739747, -0.01770206, -0.008022269, 0.044468857, 0.01187554, -0.03259911, -0.045163155, 0.005873695, -0.007031134, 0.038209956, 0.009773543, 0.018458132, 0.03298603, -0.04802215, -0.029331522, 0.009736381, 0.0014193252, -0.029266646, 0.023204679, 0.042884104, 0.036555525, 0.01989023, 0.020288104, -0.0019939796, 0.046266165, 0.009911118, -0.042073734, 0.0065396074, 0.065789275, 0.09641775, 0.017465355, 0.013128908, -0.03578239, 0.0231149, -0.021422157, -0.020437583, 0.025115158, 0.07037789, -0.0053526293, 0.0332623, -0.026476895, -0.03033616, -0.019557651, -0.03204936, 0.03887614, -0.027996426, 0.0013627007, 0.022591986, -0.049152315, -0.0028359122, -0.0057826117, 0.021139933, -0.05027323, 0.03936416, 0.04173886, -0.01125345, -0.023771996, 0.02028911, 0.0033836125, 0.031044248, 0.020033073, -0.027494857, -0.033545006, -0.058906768, 0.073347345, 0.062005993, 0.058484167, -0.00084693066, 0.005806394, 0.015744092, -0.03523072, 0.02922224, 0.0038474149, -0.0039008649, -0.015494569, -0.00070764316, -0.094965115, 0.015117273, 0.0043013617, 0.035153188, -0.061654534, 0.11085618, -0.07268279, -0.04717712, 0.032327536, -0.00704601, 0.037253235, 0.039828334, 0.00019132228, 0.028836014, -0.03307291, 0.050360598, 0.025420163, -0.015225513, -0.018811153, -0.022560537, -0.017732488, 0.020477327, 0.006707524, 0.058765963, -0.013588514, -0.020977682, 0.008896715, 0.04134574, -0.10698203, 0.004244291, -0.03720219, 0.0044170176, 0.041443963, 0.0027526275, -0.0021434748, -0.015335212, 0.0079962425, -0.02696693, -0.02288115, 0.031034293, 0.017682327, -0.05848914, -0.04479324, 0.011601903, 0.010388493, -0.017750131, -0.021489227, -0.0032729304, -0.010810562, 0.039271474, -0.005443907, -0.03595853, 0.0087571675, 0.05415203, 0.08646665, -0.013219114, 0.014869744, 0.0072967107, 0.025243847, 0.008245362, 0.018706806, -0.00870218, 0.016055388, 0.1125789, 0.007172758, -0.10118515, -0.06442794, 0.02315382, -0.06188186, -0.047224343, -0.0068433783, -0.018128177, -0.018271362, 0.02823152, 0.025293395, -0.0020494026, 0.0068809926, 0.017121902, 0.018439798, 0.03130178, -0.033437964, 0.039703637, -0.037016135, -0.037987944, 0.042977445, -0.012018748, 0.0035625743, -0.041630413, 0.017406989, -0.01154436, -0.004412928, 0.022141416, -0.0036727574, -0.008466987, 0.049739495, -0.06508093, -0.017235989, 0.02064509, 0.016321411, 0.02698845, 0.07759906, 0.017539669, -0.017168278, -0.0035778203, -0.0042685103, -0.026442358, 0.009349095, -0.029512957, -0.0065311617, -0.013559519, 0.0011971226, -0.009184269, -0.031676, -0.038088094, -0.016622547, 0.02486724, 0.032041576, -0.0055186623, 0.12189721, 0.043474462, -0.047649466, 0.027484516, -0.0035824412, -0.05383745, -0.008161388, -0.053657126, -0.0027364586, -0.00012998936, -0.022307076, -0.0486638, -0.028614787, -0.02132962, 0.0058860867, -0.06802224, 0.02570573, -0.034879185, 0.015381588, -0.047763627, -0.0032830043, -0.0015959376, -0.029630827, 0.038304392, -0.032076925, 0.021378756, -0.00052743126, -0.022812814, -0.025454491, -0.0023286757, 0.02404244, -0.0006882598, 0.0044533503, -0.0035739143, -0.06078285, -0.024933875, 0.030997192, 0.059662618, -0.054907784, 0.009324956, -0.007146112, 0.00516383, 0.030976022, -0.00035195865, -0.07011518, 0.06669572, -0.016511286, 0.031048367, 0.016499205, -0.02108085, -0.0045708157, -0.008500429, -0.25783044, 0.041272227, -0.0057234215, 0.016666386, 0.06816838, -0.009868127, 0.014825844, -0.022925615, -0.008001345, 0.046653997, -0.00014183977, -0.0026383696, -0.03135771, -0.030197483, 0.03716319, 0.0051222467, 0.033846315, -0.039608024, -0.029459938, 0.014192158, 0.015020755, -0.059405386, 0.044410657, 0.0031503357, -0.030107027, -0.032072756, -0.014434276, 0.017240832, 0.012384157, 0.027699955, 0.015897155, -0.017908351, 0.044406805, -0.06329205, 0.035939753, 0.024845755, 0.03015499, -0.0450442, -0.030212563, -0.04875517, -0.02823563, 0.05420893, 0.031548176, -0.0060583507, -0.017916419, -0.04930094, 0.020581705, -0.020350741, -0.020912305, -0.026117438, -0.04963092, -0.025120517, 0.002230628, 0.011512409, -0.023473363, -0.04301427, 0.018177832, 0.010988586, 0.027035486, 0.043955598, 0.019385587, -0.039110214, 0.07951547, 0.03305704, -0.022609217, -0.033687174, -0.032354735, -0.025954131, -0.01293125, 0.019692834, 0.00054087455, -0.03605654, 0.018381594, 0.0050960053, 0.011778557, 0.054119013, -0.018572157, 0.020884385, -0.030553969, 0.0099051595, 0.008738324, 0.03167156, -0.019423256, -0.025590187]
client.search(
    collection_name="wolt_food",
    query_vector=( search_vec),
    limit=3,
    query_filter=models.Filter(
    must=[
        models.FieldCondition(
            key="name",
            match=models.MatchAny(
                any=["Ayran", "7gün Ayran Natur"]
            ),
        )
    ]
),
)
# Out:
# [ScoredPoint(id=1451234, version=68032, score=1.0183411, payload={'cafe': {'address': 'Skt. Pauls Kirkeplads 19 st tv', 'categories': ['pizza', 'italian'], 'location': {'lat': 56.14561089999999, 'lon': 10.2045166}, 'menu_id': '60a62b0d52d7b5c7d527562b', 'name': 'Amigo Pizza og Grill', 'rating': 8.2, 'slug': 'amigo-pizza-og-grill'}, 'description': '', 'image': 'https://wolt-menu-images-cdn.wolt.com/menu-images/60a62b0d52d7b5c7d527562b/26445192-ff5b-11eb-bcc9-0ae0c111c25d_wolt_21.08.12_amigo_pizza1209.jpeg', 'image_file': '26445192-ff5b-11eb-bcc9-0ae0c111c25d_wolt_21.08.12_amigo_pizza1209.jpeg', 'name': 'Ayran'}, vector=None, shard_key=None),
# ...

# %%
# Search with filters - filtering conditions - match except

search_vec = [-0.027882958, 0.044092737, 0.0731473, 0.06553474, 0.024171988, 0.01697372, 0.0020604038, 0.018047482, -0.031200834, -0.014620315, -0.03596877, -0.008047461, 0.020798953, -0.014641951, 0.012549569, -0.029867202, 0.017640492, 0.020679252, 0.014639293, 0.02098035, -0.11850266, 0.008514167, -0.009126163, -0.03365829, -0.050205294, 0.017878275, -0.013079402, -0.03470298, 0.0053403503, -0.030538736, -0.00077569514, 0.046366554, 0.021818455, 0.048005834, 0.04522572, 0.013886643, -0.040764034, -0.019520732, -0.028808843, 0.07130225, -0.040791865, -0.010126803, -0.018052312, -0.002201882, -0.02058981, 0.03004692, -0.015570573, -0.00031868406, -0.0065039033, -0.045852456, 0.037677098, -0.007673897, 0.041015055, -0.0016164425, 0.008414605, 0.004175664, -0.050539035, -0.006734321, 0.08072506, -0.02726352, 0.03412241, -0.013328949, 0.0043830182, -0.020793792, -0.053872947, 0.012582162, 0.025352875, 0.05972377, -0.047683716, -0.040093377, -0.055419512, -0.0015524544, -0.06110616, 0.00039961239, 0.017122721, 0.011367437, 0.011612826, 0.017466443, 0.03495627, 0.037525106, 0.03702163, 0.029719371, 0.022293076, -0.103361145, -0.0051242076, -0.024882244, -0.0020247647, -0.034090083, -0.011648688, -0.0196668, 0.030498808, 0.049275327, -0.54135513, -0.0009911052, 0.05663518, 0.07849116, -0.026038505, -0.0178324, -0.035706922, -0.011421131, 0.0029203151, -0.051898856, -0.07163099, 0.023290059, -0.05910354, 0.035753418, -0.12370726, 0.00086394034, 0.062437817, 0.009168275, 0.003083251, 0.034232344, -0.02869723, -0.013457852, -0.011179466, 0.013072467, -0.003246991, -0.0380963, 0.027967058, -0.075501956, 0.0020709995, 0.009059259, 0.038587045, -0.00038104434, -0.0018610929, -0.009475333, -0.058327895, -0.0032828397, 0.004082257, -0.02602711, 0.014781226, -0.02390209, 0.0125596225, 0.08649576, 0.01703702, 0.03508497, 0.022272123, -0.04628153, -0.048454344, -0.0026485103, -0.03246412, 0.027184749, 0.009867273, 0.14205816, 0.0078798365, 0.02190687, -0.045301028, 0.040254034, -0.012405296, 0.02776755, -0.023437733, -0.010314621, 0.042177826, 0.031779177, -0.004419486, -0.04076263, -0.0052590473, 0.047290847, -0.03447568, -0.036947362, 0.031243473, -0.01243047, -0.007960975, -0.0105248885, 0.0032904854, -0.040179256, 0.022467114, -0.016306987, -0.014524242, 0.0072526056, -0.052280653, -0.012893598, -0.018354755, -0.039249703, 0.019507786, -0.03402438, -0.018815486, 0.037815843, 0.011572507, 0.01665657, 0.05349542, 0.06262594, -0.030739747, -0.01770206, -0.008022269, 0.044468857, 0.01187554, -0.03259911, -0.045163155, 0.005873695, -0.007031134, 0.038209956, 0.009773543, 0.018458132, 0.03298603, -0.04802215, -0.029331522, 0.009736381, 0.0014193252, -0.029266646, 0.023204679, 0.042884104, 0.036555525, 0.01989023, 0.020288104, -0.0019939796, 0.046266165, 0.009911118, -0.042073734, 0.0065396074, 0.065789275, 0.09641775, 0.017465355, 0.013128908, -0.03578239, 0.0231149, -0.021422157, -0.020437583, 0.025115158, 0.07037789, -0.0053526293, 0.0332623, -0.026476895, -0.03033616, -0.019557651, -0.03204936, 0.03887614, -0.027996426, 0.0013627007, 0.022591986, -0.049152315, -0.0028359122, -0.0057826117, 0.021139933, -0.05027323, 0.03936416, 0.04173886, -0.01125345, -0.023771996, 0.02028911, 0.0033836125, 0.031044248, 0.020033073, -0.027494857, -0.033545006, -0.058906768, 0.073347345, 0.062005993, 0.058484167, -0.00084693066, 0.005806394, 0.015744092, -0.03523072, 0.02922224, 0.0038474149, -0.0039008649, -0.015494569, -0.00070764316, -0.094965115, 0.015117273, 0.0043013617, 0.035153188, -0.061654534, 0.11085618, -0.07268279, -0.04717712, 0.032327536, -0.00704601, 0.037253235, 0.039828334, 0.00019132228, 0.028836014, -0.03307291, 0.050360598, 0.025420163, -0.015225513, -0.018811153, -0.022560537, -0.017732488, 0.020477327, 0.006707524, 0.058765963, -0.013588514, -0.020977682, 0.008896715, 0.04134574, -0.10698203, 0.004244291, -0.03720219, 0.0044170176, 0.041443963, 0.0027526275, -0.0021434748, -0.015335212, 0.0079962425, -0.02696693, -0.02288115, 0.031034293, 0.017682327, -0.05848914, -0.04479324, 0.011601903, 0.010388493, -0.017750131, -0.021489227, -0.0032729304, -0.010810562, 0.039271474, -0.005443907, -0.03595853, 0.0087571675, 0.05415203, 0.08646665, -0.013219114, 0.014869744, 0.0072967107, 0.025243847, 0.008245362, 0.018706806, -0.00870218, 0.016055388, 0.1125789, 0.007172758, -0.10118515, -0.06442794, 0.02315382, -0.06188186, -0.047224343, -0.0068433783, -0.018128177, -0.018271362, 0.02823152, 0.025293395, -0.0020494026, 0.0068809926, 0.017121902, 0.018439798, 0.03130178, -0.033437964, 0.039703637, -0.037016135, -0.037987944, 0.042977445, -0.012018748, 0.0035625743, -0.041630413, 0.017406989, -0.01154436, -0.004412928, 0.022141416, -0.0036727574, -0.008466987, 0.049739495, -0.06508093, -0.017235989, 0.02064509, 0.016321411, 0.02698845, 0.07759906, 0.017539669, -0.017168278, -0.0035778203, -0.0042685103, -0.026442358, 0.009349095, -0.029512957, -0.0065311617, -0.013559519, 0.0011971226, -0.009184269, -0.031676, -0.038088094, -0.016622547, 0.02486724, 0.032041576, -0.0055186623, 0.12189721, 0.043474462, -0.047649466, 0.027484516, -0.0035824412, -0.05383745, -0.008161388, -0.053657126, -0.0027364586, -0.00012998936, -0.022307076, -0.0486638, -0.028614787, -0.02132962, 0.0058860867, -0.06802224, 0.02570573, -0.034879185, 0.015381588, -0.047763627, -0.0032830043, -0.0015959376, -0.029630827, 0.038304392, -0.032076925, 0.021378756, -0.00052743126, -0.022812814, -0.025454491, -0.0023286757, 0.02404244, -0.0006882598, 0.0044533503, -0.0035739143, -0.06078285, -0.024933875, 0.030997192, 0.059662618, -0.054907784, 0.009324956, -0.007146112, 0.00516383, 0.030976022, -0.00035195865, -0.07011518, 0.06669572, -0.016511286, 0.031048367, 0.016499205, -0.02108085, -0.0045708157, -0.008500429, -0.25783044, 0.041272227, -0.0057234215, 0.016666386, 0.06816838, -0.009868127, 0.014825844, -0.022925615, -0.008001345, 0.046653997, -0.00014183977, -0.0026383696, -0.03135771, -0.030197483, 0.03716319, 0.0051222467, 0.033846315, -0.039608024, -0.029459938, 0.014192158, 0.015020755, -0.059405386, 0.044410657, 0.0031503357, -0.030107027, -0.032072756, -0.014434276, 0.017240832, 0.012384157, 0.027699955, 0.015897155, -0.017908351, 0.044406805, -0.06329205, 0.035939753, 0.024845755, 0.03015499, -0.0450442, -0.030212563, -0.04875517, -0.02823563, 0.05420893, 0.031548176, -0.0060583507, -0.017916419, -0.04930094, 0.020581705, -0.020350741, -0.020912305, -0.026117438, -0.04963092, -0.025120517, 0.002230628, 0.011512409, -0.023473363, -0.04301427, 0.018177832, 0.010988586, 0.027035486, 0.043955598, 0.019385587, -0.039110214, 0.07951547, 0.03305704, -0.022609217, -0.033687174, -0.032354735, -0.025954131, -0.01293125, 0.019692834, 0.00054087455, -0.03605654, 0.018381594, 0.0050960053, 0.011778557, 0.054119013, -0.018572157, 0.020884385, -0.030553969, 0.0099051595, 0.008738324, 0.03167156, -0.019423256, -0.025590187]
client.search(
    collection_name="wolt_food",
    query_vector=( search_vec),
    limit=3,
    query_filter=models.Filter(
    must=[
        models.FieldCondition(
            key="name",
            match=models.MatchExcept(**{"except" : [ "Ayran",]}
            ),
        )
    ]
),
)
# Out:
# [ScoredPoint(id=965826, version=45279, score=0.84921265, payload={'cafe': {'address': 'Italská 4', 'categories': ['burgers', 'dessert', 'steak', 'kebab', 'meat-fish', 'pizza', 'salad', 'turkish', 'halal'], 'location': {'lat': 50.0763128, 'lon': 14.435342}, 'menu_id': '5f17fba60e59360fa003f755', 'name': 'Pasha Kebab Bistro \n', 'rating': 9.4, 'slug': 'pasha-kebab-bistro-italska'}, 'description': 'jogurtový nápoj', 'image': 'https://wolt-menu-images-cdn.wolt.com/menu-images/5f17fba60e59360fa003f755/09b5abae-2cf0-11eb-b0fb-aea8b89b8bf3_img_8177.jpeg', 'image_file': '09b5abae-2cf0-11eb-b0fb-aea8b89b8bf3_img_8177.jpeg', 'name': 'AYRAN'}, vector=None, shard_key=None),
# ...

# %%
# Search with filters - filtering conditions - nested key

search_vec = [-0.027882958, 0.044092737, 0.0731473, 0.06553474, 0.024171988, 0.01697372, 0.0020604038, 0.018047482, -0.031200834, -0.014620315, -0.03596877, -0.008047461, 0.020798953, -0.014641951, 0.012549569, -0.029867202, 0.017640492, 0.020679252, 0.014639293, 0.02098035, -0.11850266, 0.008514167, -0.009126163, -0.03365829, -0.050205294, 0.017878275, -0.013079402, -0.03470298, 0.0053403503, -0.030538736, -0.00077569514, 0.046366554, 0.021818455, 0.048005834, 0.04522572, 0.013886643, -0.040764034, -0.019520732, -0.028808843, 0.07130225, -0.040791865, -0.010126803, -0.018052312, -0.002201882, -0.02058981, 0.03004692, -0.015570573, -0.00031868406, -0.0065039033, -0.045852456, 0.037677098, -0.007673897, 0.041015055, -0.0016164425, 0.008414605, 0.004175664, -0.050539035, -0.006734321, 0.08072506, -0.02726352, 0.03412241, -0.013328949, 0.0043830182, -0.020793792, -0.053872947, 0.012582162, 0.025352875, 0.05972377, -0.047683716, -0.040093377, -0.055419512, -0.0015524544, -0.06110616, 0.00039961239, 0.017122721, 0.011367437, 0.011612826, 0.017466443, 0.03495627, 0.037525106, 0.03702163, 0.029719371, 0.022293076, -0.103361145, -0.0051242076, -0.024882244, -0.0020247647, -0.034090083, -0.011648688, -0.0196668, 0.030498808, 0.049275327, -0.54135513, -0.0009911052, 0.05663518, 0.07849116, -0.026038505, -0.0178324, -0.035706922, -0.011421131, 0.0029203151, -0.051898856, -0.07163099, 0.023290059, -0.05910354, 0.035753418, -0.12370726, 0.00086394034, 0.062437817, 0.009168275, 0.003083251, 0.034232344, -0.02869723, -0.013457852, -0.011179466, 0.013072467, -0.003246991, -0.0380963, 0.027967058, -0.075501956, 0.0020709995, 0.009059259, 0.038587045, -0.00038104434, -0.0018610929, -0.009475333, -0.058327895, -0.0032828397, 0.004082257, -0.02602711, 0.014781226, -0.02390209, 0.0125596225, 0.08649576, 0.01703702, 0.03508497, 0.022272123, -0.04628153, -0.048454344, -0.0026485103, -0.03246412, 0.027184749, 0.009867273, 0.14205816, 0.0078798365, 0.02190687, -0.045301028, 0.040254034, -0.012405296, 0.02776755, -0.023437733, -0.010314621, 0.042177826, 0.031779177, -0.004419486, -0.04076263, -0.0052590473, 0.047290847, -0.03447568, -0.036947362, 0.031243473, -0.01243047, -0.007960975, -0.0105248885, 0.0032904854, -0.040179256, 0.022467114, -0.016306987, -0.014524242, 0.0072526056, -0.052280653, -0.012893598, -0.018354755, -0.039249703, 0.019507786, -0.03402438, -0.018815486, 0.037815843, 0.011572507, 0.01665657, 0.05349542, 0.06262594, -0.030739747, -0.01770206, -0.008022269, 0.044468857, 0.01187554, -0.03259911, -0.045163155, 0.005873695, -0.007031134, 0.038209956, 0.009773543, 0.018458132, 0.03298603, -0.04802215, -0.029331522, 0.009736381, 0.0014193252, -0.029266646, 0.023204679, 0.042884104, 0.036555525, 0.01989023, 0.020288104, -0.0019939796, 0.046266165, 0.009911118, -0.042073734, 0.0065396074, 0.065789275, 0.09641775, 0.017465355, 0.013128908, -0.03578239, 0.0231149, -0.021422157, -0.020437583, 0.025115158, 0.07037789, -0.0053526293, 0.0332623, -0.026476895, -0.03033616, -0.019557651, -0.03204936, 0.03887614, -0.027996426, 0.0013627007, 0.022591986, -0.049152315, -0.0028359122, -0.0057826117, 0.021139933, -0.05027323, 0.03936416, 0.04173886, -0.01125345, -0.023771996, 0.02028911, 0.0033836125, 0.031044248, 0.020033073, -0.027494857, -0.033545006, -0.058906768, 0.073347345, 0.062005993, 0.058484167, -0.00084693066, 0.005806394, 0.015744092, -0.03523072, 0.02922224, 0.0038474149, -0.0039008649, -0.015494569, -0.00070764316, -0.094965115, 0.015117273, 0.0043013617, 0.035153188, -0.061654534, 0.11085618, -0.07268279, -0.04717712, 0.032327536, -0.00704601, 0.037253235, 0.039828334, 0.00019132228, 0.028836014, -0.03307291, 0.050360598, 0.025420163, -0.015225513, -0.018811153, -0.022560537, -0.017732488, 0.020477327, 0.006707524, 0.058765963, -0.013588514, -0.020977682, 0.008896715, 0.04134574, -0.10698203, 0.004244291, -0.03720219, 0.0044170176, 0.041443963, 0.0027526275, -0.0021434748, -0.015335212, 0.0079962425, -0.02696693, -0.02288115, 0.031034293, 0.017682327, -0.05848914, -0.04479324, 0.011601903, 0.010388493, -0.017750131, -0.021489227, -0.0032729304, -0.010810562, 0.039271474, -0.005443907, -0.03595853, 0.0087571675, 0.05415203, 0.08646665, -0.013219114, 0.014869744, 0.0072967107, 0.025243847, 0.008245362, 0.018706806, -0.00870218, 0.016055388, 0.1125789, 0.007172758, -0.10118515, -0.06442794, 0.02315382, -0.06188186, -0.047224343, -0.0068433783, -0.018128177, -0.018271362, 0.02823152, 0.025293395, -0.0020494026, 0.0068809926, 0.017121902, 0.018439798, 0.03130178, -0.033437964, 0.039703637, -0.037016135, -0.037987944, 0.042977445, -0.012018748, 0.0035625743, -0.041630413, 0.017406989, -0.01154436, -0.004412928, 0.022141416, -0.0036727574, -0.008466987, 0.049739495, -0.06508093, -0.017235989, 0.02064509, 0.016321411, 0.02698845, 0.07759906, 0.017539669, -0.017168278, -0.0035778203, -0.0042685103, -0.026442358, 0.009349095, -0.029512957, -0.0065311617, -0.013559519, 0.0011971226, -0.009184269, -0.031676, -0.038088094, -0.016622547, 0.02486724, 0.032041576, -0.0055186623, 0.12189721, 0.043474462, -0.047649466, 0.027484516, -0.0035824412, -0.05383745, -0.008161388, -0.053657126, -0.0027364586, -0.00012998936, -0.022307076, -0.0486638, -0.028614787, -0.02132962, 0.0058860867, -0.06802224, 0.02570573, -0.034879185, 0.015381588, -0.047763627, -0.0032830043, -0.0015959376, -0.029630827, 0.038304392, -0.032076925, 0.021378756, -0.00052743126, -0.022812814, -0.025454491, -0.0023286757, 0.02404244, -0.0006882598, 0.0044533503, -0.0035739143, -0.06078285, -0.024933875, 0.030997192, 0.059662618, -0.054907784, 0.009324956, -0.007146112, 0.00516383, 0.030976022, -0.00035195865, -0.07011518, 0.06669572, -0.016511286, 0.031048367, 0.016499205, -0.02108085, -0.0045708157, -0.008500429, -0.25783044, 0.041272227, -0.0057234215, 0.016666386, 0.06816838, -0.009868127, 0.014825844, -0.022925615, -0.008001345, 0.046653997, -0.00014183977, -0.0026383696, -0.03135771, -0.030197483, 0.03716319, 0.0051222467, 0.033846315, -0.039608024, -0.029459938, 0.014192158, 0.015020755, -0.059405386, 0.044410657, 0.0031503357, -0.030107027, -0.032072756, -0.014434276, 0.017240832, 0.012384157, 0.027699955, 0.015897155, -0.017908351, 0.044406805, -0.06329205, 0.035939753, 0.024845755, 0.03015499, -0.0450442, -0.030212563, -0.04875517, -0.02823563, 0.05420893, 0.031548176, -0.0060583507, -0.017916419, -0.04930094, 0.020581705, -0.020350741, -0.020912305, -0.026117438, -0.04963092, -0.025120517, 0.002230628, 0.011512409, -0.023473363, -0.04301427, 0.018177832, 0.010988586, 0.027035486, 0.043955598, 0.019385587, -0.039110214, 0.07951547, 0.03305704, -0.022609217, -0.033687174, -0.032354735, -0.025954131, -0.01293125, 0.019692834, 0.00054087455, -0.03605654, 0.018381594, 0.0050960053, 0.011778557, 0.054119013, -0.018572157, 0.020884385, -0.030553969, 0.0099051595, 0.008738324, 0.03167156, -0.019423256, -0.025590187]
client.search(
    collection_name="wolt_food",
    query_vector=( search_vec),
    limit=3,
    query_filter=models.Filter(
    must=[
        models.FieldCondition(
            key="cafe.address",
            match=models.MatchValue(value="Italská 4")
            )
    ]
),
)
# Out:
# [ScoredPoint(id=965826, version=45279, score=0.84921265, payload={'cafe': {'address': 'Italská 4', 'categories': ['burgers', 'dessert', 'steak', 'kebab', 'meat-fish', 'pizza', 'salad', 'turkish', 'halal'], 'location': {'lat': 50.0763128, 'lon': 14.435342}, 'menu_id': '5f17fba60e59360fa003f755', 'name': 'Pasha Kebab Bistro \n', 'rating': 9.4, 'slug': 'pasha-kebab-bistro-italska'}, 'description': 'jogurtový nápoj', 'image': 'https://wolt-menu-images-cdn.wolt.com/menu-images/5f17fba60e59360fa003f755/09b5abae-2cf0-11eb-b0fb-aea8b89b8bf3_img_8177.jpeg', 'image_file': '09b5abae-2cf0-11eb-b0fb-aea8b89b8bf3_img_8177.jpeg', 'name': 'AYRAN'}, vector=None, shard_key=None),
# ...

# %%
# Search with filters - filtering conditions - match text

search_vec = [-0.027882958, 0.044092737, 0.0731473, 0.06553474, 0.024171988, 0.01697372, 0.0020604038, 0.018047482, -0.031200834, -0.014620315, -0.03596877, -0.008047461, 0.020798953, -0.014641951, 0.012549569, -0.029867202, 0.017640492, 0.020679252, 0.014639293, 0.02098035, -0.11850266, 0.008514167, -0.009126163, -0.03365829, -0.050205294, 0.017878275, -0.013079402, -0.03470298, 0.0053403503, -0.030538736, -0.00077569514, 0.046366554, 0.021818455, 0.048005834, 0.04522572, 0.013886643, -0.040764034, -0.019520732, -0.028808843, 0.07130225, -0.040791865, -0.010126803, -0.018052312, -0.002201882, -0.02058981, 0.03004692, -0.015570573, -0.00031868406, -0.0065039033, -0.045852456, 0.037677098, -0.007673897, 0.041015055, -0.0016164425, 0.008414605, 0.004175664, -0.050539035, -0.006734321, 0.08072506, -0.02726352, 0.03412241, -0.013328949, 0.0043830182, -0.020793792, -0.053872947, 0.012582162, 0.025352875, 0.05972377, -0.047683716, -0.040093377, -0.055419512, -0.0015524544, -0.06110616, 0.00039961239, 0.017122721, 0.011367437, 0.011612826, 0.017466443, 0.03495627, 0.037525106, 0.03702163, 0.029719371, 0.022293076, -0.103361145, -0.0051242076, -0.024882244, -0.0020247647, -0.034090083, -0.011648688, -0.0196668, 0.030498808, 0.049275327, -0.54135513, -0.0009911052, 0.05663518, 0.07849116, -0.026038505, -0.0178324, -0.035706922, -0.011421131, 0.0029203151, -0.051898856, -0.07163099, 0.023290059, -0.05910354, 0.035753418, -0.12370726, 0.00086394034, 0.062437817, 0.009168275, 0.003083251, 0.034232344, -0.02869723, -0.013457852, -0.011179466, 0.013072467, -0.003246991, -0.0380963, 0.027967058, -0.075501956, 0.0020709995, 0.009059259, 0.038587045, -0.00038104434, -0.0018610929, -0.009475333, -0.058327895, -0.0032828397, 0.004082257, -0.02602711, 0.014781226, -0.02390209, 0.0125596225, 0.08649576, 0.01703702, 0.03508497, 0.022272123, -0.04628153, -0.048454344, -0.0026485103, -0.03246412, 0.027184749, 0.009867273, 0.14205816, 0.0078798365, 0.02190687, -0.045301028, 0.040254034, -0.012405296, 0.02776755, -0.023437733, -0.010314621, 0.042177826, 0.031779177, -0.004419486, -0.04076263, -0.0052590473, 0.047290847, -0.03447568, -0.036947362, 0.031243473, -0.01243047, -0.007960975, -0.0105248885, 0.0032904854, -0.040179256, 0.022467114, -0.016306987, -0.014524242, 0.0072526056, -0.052280653, -0.012893598, -0.018354755, -0.039249703, 0.019507786, -0.03402438, -0.018815486, 0.037815843, 0.011572507, 0.01665657, 0.05349542, 0.06262594, -0.030739747, -0.01770206, -0.008022269, 0.044468857, 0.01187554, -0.03259911, -0.045163155, 0.005873695, -0.007031134, 0.038209956, 0.009773543, 0.018458132, 0.03298603, -0.04802215, -0.029331522, 0.009736381, 0.0014193252, -0.029266646, 0.023204679, 0.042884104, 0.036555525, 0.01989023, 0.020288104, -0.0019939796, 0.046266165, 0.009911118, -0.042073734, 0.0065396074, 0.065789275, 0.09641775, 0.017465355, 0.013128908, -0.03578239, 0.0231149, -0.021422157, -0.020437583, 0.025115158, 0.07037789, -0.0053526293, 0.0332623, -0.026476895, -0.03033616, -0.019557651, -0.03204936, 0.03887614, -0.027996426, 0.0013627007, 0.022591986, -0.049152315, -0.0028359122, -0.0057826117, 0.021139933, -0.05027323, 0.03936416, 0.04173886, -0.01125345, -0.023771996, 0.02028911, 0.0033836125, 0.031044248, 0.020033073, -0.027494857, -0.033545006, -0.058906768, 0.073347345, 0.062005993, 0.058484167, -0.00084693066, 0.005806394, 0.015744092, -0.03523072, 0.02922224, 0.0038474149, -0.0039008649, -0.015494569, -0.00070764316, -0.094965115, 0.015117273, 0.0043013617, 0.035153188, -0.061654534, 0.11085618, -0.07268279, -0.04717712, 0.032327536, -0.00704601, 0.037253235, 0.039828334, 0.00019132228, 0.028836014, -0.03307291, 0.050360598, 0.025420163, -0.015225513, -0.018811153, -0.022560537, -0.017732488, 0.020477327, 0.006707524, 0.058765963, -0.013588514, -0.020977682, 0.008896715, 0.04134574, -0.10698203, 0.004244291, -0.03720219, 0.0044170176, 0.041443963, 0.0027526275, -0.0021434748, -0.015335212, 0.0079962425, -0.02696693, -0.02288115, 0.031034293, 0.017682327, -0.05848914, -0.04479324, 0.011601903, 0.010388493, -0.017750131, -0.021489227, -0.0032729304, -0.010810562, 0.039271474, -0.005443907, -0.03595853, 0.0087571675, 0.05415203, 0.08646665, -0.013219114, 0.014869744, 0.0072967107, 0.025243847, 0.008245362, 0.018706806, -0.00870218, 0.016055388, 0.1125789, 0.007172758, -0.10118515, -0.06442794, 0.02315382, -0.06188186, -0.047224343, -0.0068433783, -0.018128177, -0.018271362, 0.02823152, 0.025293395, -0.0020494026, 0.0068809926, 0.017121902, 0.018439798, 0.03130178, -0.033437964, 0.039703637, -0.037016135, -0.037987944, 0.042977445, -0.012018748, 0.0035625743, -0.041630413, 0.017406989, -0.01154436, -0.004412928, 0.022141416, -0.0036727574, -0.008466987, 0.049739495, -0.06508093, -0.017235989, 0.02064509, 0.016321411, 0.02698845, 0.07759906, 0.017539669, -0.017168278, -0.0035778203, -0.0042685103, -0.026442358, 0.009349095, -0.029512957, -0.0065311617, -0.013559519, 0.0011971226, -0.009184269, -0.031676, -0.038088094, -0.016622547, 0.02486724, 0.032041576, -0.0055186623, 0.12189721, 0.043474462, -0.047649466, 0.027484516, -0.0035824412, -0.05383745, -0.008161388, -0.053657126, -0.0027364586, -0.00012998936, -0.022307076, -0.0486638, -0.028614787, -0.02132962, 0.0058860867, -0.06802224, 0.02570573, -0.034879185, 0.015381588, -0.047763627, -0.0032830043, -0.0015959376, -0.029630827, 0.038304392, -0.032076925, 0.021378756, -0.00052743126, -0.022812814, -0.025454491, -0.0023286757, 0.02404244, -0.0006882598, 0.0044533503, -0.0035739143, -0.06078285, -0.024933875, 0.030997192, 0.059662618, -0.054907784, 0.009324956, -0.007146112, 0.00516383, 0.030976022, -0.00035195865, -0.07011518, 0.06669572, -0.016511286, 0.031048367, 0.016499205, -0.02108085, -0.0045708157, -0.008500429, -0.25783044, 0.041272227, -0.0057234215, 0.016666386, 0.06816838, -0.009868127, 0.014825844, -0.022925615, -0.008001345, 0.046653997, -0.00014183977, -0.0026383696, -0.03135771, -0.030197483, 0.03716319, 0.0051222467, 0.033846315, -0.039608024, -0.029459938, 0.014192158, 0.015020755, -0.059405386, 0.044410657, 0.0031503357, -0.030107027, -0.032072756, -0.014434276, 0.017240832, 0.012384157, 0.027699955, 0.015897155, -0.017908351, 0.044406805, -0.06329205, 0.035939753, 0.024845755, 0.03015499, -0.0450442, -0.030212563, -0.04875517, -0.02823563, 0.05420893, 0.031548176, -0.0060583507, -0.017916419, -0.04930094, 0.020581705, -0.020350741, -0.020912305, -0.026117438, -0.04963092, -0.025120517, 0.002230628, 0.011512409, -0.023473363, -0.04301427, 0.018177832, 0.010988586, 0.027035486, 0.043955598, 0.019385587, -0.039110214, 0.07951547, 0.03305704, -0.022609217, -0.033687174, -0.032354735, -0.025954131, -0.01293125, 0.019692834, 0.00054087455, -0.03605654, 0.018381594, 0.0050960053, 0.011778557, 0.054119013, -0.018572157, 0.020884385, -0.030553969, 0.0099051595, 0.008738324, 0.03167156, -0.019423256, -0.025590187]
client.search(
    collection_name="wolt_food",
    query_vector=( search_vec),
    limit=3,
    query_filter=models.Filter(
    must=[
        models.FieldCondition(
            key="cafe.address",
            match=models.MatchText(text="Pauls")
            )
    ]
),
)
# Out:
# [ScoredPoint(id=1451234, version=68032, score=1.0183411, payload={'cafe': {'address': 'Skt. Pauls Kirkeplads 19 st tv', 'categories': ['pizza', 'italian'], 'location': {'lat': 56.14561089999999, 'lon': 10.2045166}, 'menu_id': '60a62b0d52d7b5c7d527562b', 'name': 'Amigo Pizza og Grill', 'rating': 8.2, 'slug': 'amigo-pizza-og-grill'}, 'description': '', 'image': 'https://wolt-menu-images-cdn.wolt.com/menu-images/60a62b0d52d7b5c7d527562b/26445192-ff5b-11eb-bcc9-0ae0c111c25d_wolt_21.08.12_amigo_pizza1209.jpeg', 'image_file': '26445192-ff5b-11eb-bcc9-0ae0c111c25d_wolt_21.08.12_amigo_pizza1209.jpeg', 'name': 'Ayran'}, vector=None, shard_key=None),
# ...

# %%
# Search with filters - filtering conditions - match range

search_vec = [-0.027882958, 0.044092737, 0.0731473, 0.06553474, 0.024171988, 0.01697372, 0.0020604038, 0.018047482, -0.031200834, -0.014620315, -0.03596877, -0.008047461, 0.020798953, -0.014641951, 0.012549569, -0.029867202, 0.017640492, 0.020679252, 0.014639293, 0.02098035, -0.11850266, 0.008514167, -0.009126163, -0.03365829, -0.050205294, 0.017878275, -0.013079402, -0.03470298, 0.0053403503, -0.030538736, -0.00077569514, 0.046366554, 0.021818455, 0.048005834, 0.04522572, 0.013886643, -0.040764034, -0.019520732, -0.028808843, 0.07130225, -0.040791865, -0.010126803, -0.018052312, -0.002201882, -0.02058981, 0.03004692, -0.015570573, -0.00031868406, -0.0065039033, -0.045852456, 0.037677098, -0.007673897, 0.041015055, -0.0016164425, 0.008414605, 0.004175664, -0.050539035, -0.006734321, 0.08072506, -0.02726352, 0.03412241, -0.013328949, 0.0043830182, -0.020793792, -0.053872947, 0.012582162, 0.025352875, 0.05972377, -0.047683716, -0.040093377, -0.055419512, -0.0015524544, -0.06110616, 0.00039961239, 0.017122721, 0.011367437, 0.011612826, 0.017466443, 0.03495627, 0.037525106, 0.03702163, 0.029719371, 0.022293076, -0.103361145, -0.0051242076, -0.024882244, -0.0020247647, -0.034090083, -0.011648688, -0.0196668, 0.030498808, 0.049275327, -0.54135513, -0.0009911052, 0.05663518, 0.07849116, -0.026038505, -0.0178324, -0.035706922, -0.011421131, 0.0029203151, -0.051898856, -0.07163099, 0.023290059, -0.05910354, 0.035753418, -0.12370726, 0.00086394034, 0.062437817, 0.009168275, 0.003083251, 0.034232344, -0.02869723, -0.013457852, -0.011179466, 0.013072467, -0.003246991, -0.0380963, 0.027967058, -0.075501956, 0.0020709995, 0.009059259, 0.038587045, -0.00038104434, -0.0018610929, -0.009475333, -0.058327895, -0.0032828397, 0.004082257, -0.02602711, 0.014781226, -0.02390209, 0.0125596225, 0.08649576, 0.01703702, 0.03508497, 0.022272123, -0.04628153, -0.048454344, -0.0026485103, -0.03246412, 0.027184749, 0.009867273, 0.14205816, 0.0078798365, 0.02190687, -0.045301028, 0.040254034, -0.012405296, 0.02776755, -0.023437733, -0.010314621, 0.042177826, 0.031779177, -0.004419486, -0.04076263, -0.0052590473, 0.047290847, -0.03447568, -0.036947362, 0.031243473, -0.01243047, -0.007960975, -0.0105248885, 0.0032904854, -0.040179256, 0.022467114, -0.016306987, -0.014524242, 0.0072526056, -0.052280653, -0.012893598, -0.018354755, -0.039249703, 0.019507786, -0.03402438, -0.018815486, 0.037815843, 0.011572507, 0.01665657, 0.05349542, 0.06262594, -0.030739747, -0.01770206, -0.008022269, 0.044468857, 0.01187554, -0.03259911, -0.045163155, 0.005873695, -0.007031134, 0.038209956, 0.009773543, 0.018458132, 0.03298603, -0.04802215, -0.029331522, 0.009736381, 0.0014193252, -0.029266646, 0.023204679, 0.042884104, 0.036555525, 0.01989023, 0.020288104, -0.0019939796, 0.046266165, 0.009911118, -0.042073734, 0.0065396074, 0.065789275, 0.09641775, 0.017465355, 0.013128908, -0.03578239, 0.0231149, -0.021422157, -0.020437583, 0.025115158, 0.07037789, -0.0053526293, 0.0332623, -0.026476895, -0.03033616, -0.019557651, -0.03204936, 0.03887614, -0.027996426, 0.0013627007, 0.022591986, -0.049152315, -0.0028359122, -0.0057826117, 0.021139933, -0.05027323, 0.03936416, 0.04173886, -0.01125345, -0.023771996, 0.02028911, 0.0033836125, 0.031044248, 0.020033073, -0.027494857, -0.033545006, -0.058906768, 0.073347345, 0.062005993, 0.058484167, -0.00084693066, 0.005806394, 0.015744092, -0.03523072, 0.02922224, 0.0038474149, -0.0039008649, -0.015494569, -0.00070764316, -0.094965115, 0.015117273, 0.0043013617, 0.035153188, -0.061654534, 0.11085618, -0.07268279, -0.04717712, 0.032327536, -0.00704601, 0.037253235, 0.039828334, 0.00019132228, 0.028836014, -0.03307291, 0.050360598, 0.025420163, -0.015225513, -0.018811153, -0.022560537, -0.017732488, 0.020477327, 0.006707524, 0.058765963, -0.013588514, -0.020977682, 0.008896715, 0.04134574, -0.10698203, 0.004244291, -0.03720219, 0.0044170176, 0.041443963, 0.0027526275, -0.0021434748, -0.015335212, 0.0079962425, -0.02696693, -0.02288115, 0.031034293, 0.017682327, -0.05848914, -0.04479324, 0.011601903, 0.010388493, -0.017750131, -0.021489227, -0.0032729304, -0.010810562, 0.039271474, -0.005443907, -0.03595853, 0.0087571675, 0.05415203, 0.08646665, -0.013219114, 0.014869744, 0.0072967107, 0.025243847, 0.008245362, 0.018706806, -0.00870218, 0.016055388, 0.1125789, 0.007172758, -0.10118515, -0.06442794, 0.02315382, -0.06188186, -0.047224343, -0.0068433783, -0.018128177, -0.018271362, 0.02823152, 0.025293395, -0.0020494026, 0.0068809926, 0.017121902, 0.018439798, 0.03130178, -0.033437964, 0.039703637, -0.037016135, -0.037987944, 0.042977445, -0.012018748, 0.0035625743, -0.041630413, 0.017406989, -0.01154436, -0.004412928, 0.022141416, -0.0036727574, -0.008466987, 0.049739495, -0.06508093, -0.017235989, 0.02064509, 0.016321411, 0.02698845, 0.07759906, 0.017539669, -0.017168278, -0.0035778203, -0.0042685103, -0.026442358, 0.009349095, -0.029512957, -0.0065311617, -0.013559519, 0.0011971226, -0.009184269, -0.031676, -0.038088094, -0.016622547, 0.02486724, 0.032041576, -0.0055186623, 0.12189721, 0.043474462, -0.047649466, 0.027484516, -0.0035824412, -0.05383745, -0.008161388, -0.053657126, -0.0027364586, -0.00012998936, -0.022307076, -0.0486638, -0.028614787, -0.02132962, 0.0058860867, -0.06802224, 0.02570573, -0.034879185, 0.015381588, -0.047763627, -0.0032830043, -0.0015959376, -0.029630827, 0.038304392, -0.032076925, 0.021378756, -0.00052743126, -0.022812814, -0.025454491, -0.0023286757, 0.02404244, -0.0006882598, 0.0044533503, -0.0035739143, -0.06078285, -0.024933875, 0.030997192, 0.059662618, -0.054907784, 0.009324956, -0.007146112, 0.00516383, 0.030976022, -0.00035195865, -0.07011518, 0.06669572, -0.016511286, 0.031048367, 0.016499205, -0.02108085, -0.0045708157, -0.008500429, -0.25783044, 0.041272227, -0.0057234215, 0.016666386, 0.06816838, -0.009868127, 0.014825844, -0.022925615, -0.008001345, 0.046653997, -0.00014183977, -0.0026383696, -0.03135771, -0.030197483, 0.03716319, 0.0051222467, 0.033846315, -0.039608024, -0.029459938, 0.014192158, 0.015020755, -0.059405386, 0.044410657, 0.0031503357, -0.030107027, -0.032072756, -0.014434276, 0.017240832, 0.012384157, 0.027699955, 0.015897155, -0.017908351, 0.044406805, -0.06329205, 0.035939753, 0.024845755, 0.03015499, -0.0450442, -0.030212563, -0.04875517, -0.02823563, 0.05420893, 0.031548176, -0.0060583507, -0.017916419, -0.04930094, 0.020581705, -0.020350741, -0.020912305, -0.026117438, -0.04963092, -0.025120517, 0.002230628, 0.011512409, -0.023473363, -0.04301427, 0.018177832, 0.010988586, 0.027035486, 0.043955598, 0.019385587, -0.039110214, 0.07951547, 0.03305704, -0.022609217, -0.033687174, -0.032354735, -0.025954131, -0.01293125, 0.019692834, 0.00054087455, -0.03605654, 0.018381594, 0.0050960053, 0.011778557, 0.054119013, -0.018572157, 0.020884385, -0.030553969, 0.0099051595, 0.008738324, 0.03167156, -0.019423256, -0.025590187]
client.search(
    collection_name="wolt_food",
    query_vector=( search_vec),
    limit=3,
    query_filter=models.Filter(
    must=[
        models.FieldCondition(
                key="cafe.rating",
    range=models.Range(
        gt=9.0,
        gte=9.99
    ),
        )
    ]
),
)
# Out:
# [ScoredPoint(id=677923, version=31782, score=0.7920227, payload={'cafe': {'address': 'Larnacos Avenue 33', 'categories': ['healthy'], 'location': {'lat': 35.17103111436659, 'lon': 33.37547387478922}, 'menu_id': '60586f6dcaa97054930a69f3', 'name': 'Etherio Larnacos Av.', 'rating': 10.0, 'slug': 'etherio-larnacos-avenue'}, 'description': 'Yogurt, desserts\n1 pc(s), 1.15 EUR /pc', 'image': 'https://wolt-menu-images-cdn.wolt.com/menu-images/60544797dd99410763c552fc/5e1dd7ba-8af2-11eb-8c2c-8af53a96fe4d_wolt_aitherio_612.jpeg', 'image_file': '5e1dd7ba-8af2-11eb-8c2c-8af53a96fe4d_wolt_aitherio_612.jpeg', 'name': 'Charalambides Christis Strained Goat Yogurt 100g Bio'}, vector=None, shard_key=None),
# ...

# %%
# Search with filters - filtering conditions - Geo - Bounding Box

search_vec = [-0.027882958, 0.044092737, 0.0731473, 0.06553474, 0.024171988, 0.01697372, 0.0020604038, 0.018047482, -0.031200834, -0.014620315, -0.03596877, -0.008047461, 0.020798953, -0.014641951, 0.012549569, -0.029867202, 0.017640492, 0.020679252, 0.014639293, 0.02098035, -0.11850266, 0.008514167, -0.009126163, -0.03365829, -0.050205294, 0.017878275, -0.013079402, -0.03470298, 0.0053403503, -0.030538736, -0.00077569514, 0.046366554, 0.021818455, 0.048005834, 0.04522572, 0.013886643, -0.040764034, -0.019520732, -0.028808843, 0.07130225, -0.040791865, -0.010126803, -0.018052312, -0.002201882, -0.02058981, 0.03004692, -0.015570573, -0.00031868406, -0.0065039033, -0.045852456, 0.037677098, -0.007673897, 0.041015055, -0.0016164425, 0.008414605, 0.004175664, -0.050539035, -0.006734321, 0.08072506, -0.02726352, 0.03412241, -0.013328949, 0.0043830182, -0.020793792, -0.053872947, 0.012582162, 0.025352875, 0.05972377, -0.047683716, -0.040093377, -0.055419512, -0.0015524544, -0.06110616, 0.00039961239, 0.017122721, 0.011367437, 0.011612826, 0.017466443, 0.03495627, 0.037525106, 0.03702163, 0.029719371, 0.022293076, -0.103361145, -0.0051242076, -0.024882244, -0.0020247647, -0.034090083, -0.011648688, -0.0196668, 0.030498808, 0.049275327, -0.54135513, -0.0009911052, 0.05663518, 0.07849116, -0.026038505, -0.0178324, -0.035706922, -0.011421131, 0.0029203151, -0.051898856, -0.07163099, 0.023290059, -0.05910354, 0.035753418, -0.12370726, 0.00086394034, 0.062437817, 0.009168275, 0.003083251, 0.034232344, -0.02869723, -0.013457852, -0.011179466, 0.013072467, -0.003246991, -0.0380963, 0.027967058, -0.075501956, 0.0020709995, 0.009059259, 0.038587045, -0.00038104434, -0.0018610929, -0.009475333, -0.058327895, -0.0032828397, 0.004082257, -0.02602711, 0.014781226, -0.02390209, 0.0125596225, 0.08649576, 0.01703702, 0.03508497, 0.022272123, -0.04628153, -0.048454344, -0.0026485103, -0.03246412, 0.027184749, 0.009867273, 0.14205816, 0.0078798365, 0.02190687, -0.045301028, 0.040254034, -0.012405296, 0.02776755, -0.023437733, -0.010314621, 0.042177826, 0.031779177, -0.004419486, -0.04076263, -0.0052590473, 0.047290847, -0.03447568, -0.036947362, 0.031243473, -0.01243047, -0.007960975, -0.0105248885, 0.0032904854, -0.040179256, 0.022467114, -0.016306987, -0.014524242, 0.0072526056, -0.052280653, -0.012893598, -0.018354755, -0.039249703, 0.019507786, -0.03402438, -0.018815486, 0.037815843, 0.011572507, 0.01665657, 0.05349542, 0.06262594, -0.030739747, -0.01770206, -0.008022269, 0.044468857, 0.01187554, -0.03259911, -0.045163155, 0.005873695, -0.007031134, 0.038209956, 0.009773543, 0.018458132, 0.03298603, -0.04802215, -0.029331522, 0.009736381, 0.0014193252, -0.029266646, 0.023204679, 0.042884104, 0.036555525, 0.01989023, 0.020288104, -0.0019939796, 0.046266165, 0.009911118, -0.042073734, 0.0065396074, 0.065789275, 0.09641775, 0.017465355, 0.013128908, -0.03578239, 0.0231149, -0.021422157, -0.020437583, 0.025115158, 0.07037789, -0.0053526293, 0.0332623, -0.026476895, -0.03033616, -0.019557651, -0.03204936, 0.03887614, -0.027996426, 0.0013627007, 0.022591986, -0.049152315, -0.0028359122, -0.0057826117, 0.021139933, -0.05027323, 0.03936416, 0.04173886, -0.01125345, -0.023771996, 0.02028911, 0.0033836125, 0.031044248, 0.020033073, -0.027494857, -0.033545006, -0.058906768, 0.073347345, 0.062005993, 0.058484167, -0.00084693066, 0.005806394, 0.015744092, -0.03523072, 0.02922224, 0.0038474149, -0.0039008649, -0.015494569, -0.00070764316, -0.094965115, 0.015117273, 0.0043013617, 0.035153188, -0.061654534, 0.11085618, -0.07268279, -0.04717712, 0.032327536, -0.00704601, 0.037253235, 0.039828334, 0.00019132228, 0.028836014, -0.03307291, 0.050360598, 0.025420163, -0.015225513, -0.018811153, -0.022560537, -0.017732488, 0.020477327, 0.006707524, 0.058765963, -0.013588514, -0.020977682, 0.008896715, 0.04134574, -0.10698203, 0.004244291, -0.03720219, 0.0044170176, 0.041443963, 0.0027526275, -0.0021434748, -0.015335212, 0.0079962425, -0.02696693, -0.02288115, 0.031034293, 0.017682327, -0.05848914, -0.04479324, 0.011601903, 0.010388493, -0.017750131, -0.021489227, -0.0032729304, -0.010810562, 0.039271474, -0.005443907, -0.03595853, 0.0087571675, 0.05415203, 0.08646665, -0.013219114, 0.014869744, 0.0072967107, 0.025243847, 0.008245362, 0.018706806, -0.00870218, 0.016055388, 0.1125789, 0.007172758, -0.10118515, -0.06442794, 0.02315382, -0.06188186, -0.047224343, -0.0068433783, -0.018128177, -0.018271362, 0.02823152, 0.025293395, -0.0020494026, 0.0068809926, 0.017121902, 0.018439798, 0.03130178, -0.033437964, 0.039703637, -0.037016135, -0.037987944, 0.042977445, -0.012018748, 0.0035625743, -0.041630413, 0.017406989, -0.01154436, -0.004412928, 0.022141416, -0.0036727574, -0.008466987, 0.049739495, -0.06508093, -0.017235989, 0.02064509, 0.016321411, 0.02698845, 0.07759906, 0.017539669, -0.017168278, -0.0035778203, -0.0042685103, -0.026442358, 0.009349095, -0.029512957, -0.0065311617, -0.013559519, 0.0011971226, -0.009184269, -0.031676, -0.038088094, -0.016622547, 0.02486724, 0.032041576, -0.0055186623, 0.12189721, 0.043474462, -0.047649466, 0.027484516, -0.0035824412, -0.05383745, -0.008161388, -0.053657126, -0.0027364586, -0.00012998936, -0.022307076, -0.0486638, -0.028614787, -0.02132962, 0.0058860867, -0.06802224, 0.02570573, -0.034879185, 0.015381588, -0.047763627, -0.0032830043, -0.0015959376, -0.029630827, 0.038304392, -0.032076925, 0.021378756, -0.00052743126, -0.022812814, -0.025454491, -0.0023286757, 0.02404244, -0.0006882598, 0.0044533503, -0.0035739143, -0.06078285, -0.024933875, 0.030997192, 0.059662618, -0.054907784, 0.009324956, -0.007146112, 0.00516383, 0.030976022, -0.00035195865, -0.07011518, 0.06669572, -0.016511286, 0.031048367, 0.016499205, -0.02108085, -0.0045708157, -0.008500429, -0.25783044, 0.041272227, -0.0057234215, 0.016666386, 0.06816838, -0.009868127, 0.014825844, -0.022925615, -0.008001345, 0.046653997, -0.00014183977, -0.0026383696, -0.03135771, -0.030197483, 0.03716319, 0.0051222467, 0.033846315, -0.039608024, -0.029459938, 0.014192158, 0.015020755, -0.059405386, 0.044410657, 0.0031503357, -0.030107027, -0.032072756, -0.014434276, 0.017240832, 0.012384157, 0.027699955, 0.015897155, -0.017908351, 0.044406805, -0.06329205, 0.035939753, 0.024845755, 0.03015499, -0.0450442, -0.030212563, -0.04875517, -0.02823563, 0.05420893, 0.031548176, -0.0060583507, -0.017916419, -0.04930094, 0.020581705, -0.020350741, -0.020912305, -0.026117438, -0.04963092, -0.025120517, 0.002230628, 0.011512409, -0.023473363, -0.04301427, 0.018177832, 0.010988586, 0.027035486, 0.043955598, 0.019385587, -0.039110214, 0.07951547, 0.03305704, -0.022609217, -0.033687174, -0.032354735, -0.025954131, -0.01293125, 0.019692834, 0.00054087455, -0.03605654, 0.018381594, 0.0050960053, 0.011778557, 0.054119013, -0.018572157, 0.020884385, -0.030553969, 0.0099051595, 0.008738324, 0.03167156, -0.019423256, -0.025590187]
client.search(
    collection_name="wolt_food",
    query_vector=( search_vec),
    limit=3,
    query_filter=models.Filter(
    must=[
        models.FieldCondition(
    key="cafe.location",
    geo_bounding_box=models.GeoBoundingBox(
        bottom_right=models.GeoPoint(
            lon=33.38,
            lat=35.16,
        ),
        top_left=models.GeoPoint(
            lon=33.36,
            lat=35.18,
        ),
    ),
)]
),
)
# Out:
# [ScoredPoint(id=677923, version=31782, score=0.7920227, payload={'cafe': {'address': 'Larnacos Avenue 33', 'categories': ['healthy'], 'location': {'lat': 35.17103111436659, 'lon': 33.37547387478922}, 'menu_id': '60586f6dcaa97054930a69f3', 'name': 'Etherio Larnacos Av.', 'rating': 10.0, 'slug': 'etherio-larnacos-avenue'}, 'description': 'Yogurt, desserts\n1 pc(s), 1.15 EUR /pc', 'image': 'https://wolt-menu-images-cdn.wolt.com/menu-images/60544797dd99410763c552fc/5e1dd7ba-8af2-11eb-8c2c-8af53a96fe4d_wolt_aitherio_612.jpeg', 'image_file': '5e1dd7ba-8af2-11eb-8c2c-8af53a96fe4d_wolt_aitherio_612.jpeg', 'name': 'Charalambides Christis Strained Goat Yogurt 100g Bio'}, vector=None, shard_key=None),
# ...

# %%
# Search with filters - filtering conditions - Geo - Radius

search_vec = [-0.027882958, 0.044092737, 0.0731473, 0.06553474, 0.024171988, 0.01697372, 0.0020604038, 0.018047482, -0.031200834, -0.014620315, -0.03596877, -0.008047461, 0.020798953, -0.014641951, 0.012549569, -0.029867202, 0.017640492, 0.020679252, 0.014639293, 0.02098035, -0.11850266, 0.008514167, -0.009126163, -0.03365829, -0.050205294, 0.017878275, -0.013079402, -0.03470298, 0.0053403503, -0.030538736, -0.00077569514, 0.046366554, 0.021818455, 0.048005834, 0.04522572, 0.013886643, -0.040764034, -0.019520732, -0.028808843, 0.07130225, -0.040791865, -0.010126803, -0.018052312, -0.002201882, -0.02058981, 0.03004692, -0.015570573, -0.00031868406, -0.0065039033, -0.045852456, 0.037677098, -0.007673897, 0.041015055, -0.0016164425, 0.008414605, 0.004175664, -0.050539035, -0.006734321, 0.08072506, -0.02726352, 0.03412241, -0.013328949, 0.0043830182, -0.020793792, -0.053872947, 0.012582162, 0.025352875, 0.05972377, -0.047683716, -0.040093377, -0.055419512, -0.0015524544, -0.06110616, 0.00039961239, 0.017122721, 0.011367437, 0.011612826, 0.017466443, 0.03495627, 0.037525106, 0.03702163, 0.029719371, 0.022293076, -0.103361145, -0.0051242076, -0.024882244, -0.0020247647, -0.034090083, -0.011648688, -0.0196668, 0.030498808, 0.049275327, -0.54135513, -0.0009911052, 0.05663518, 0.07849116, -0.026038505, -0.0178324, -0.035706922, -0.011421131, 0.0029203151, -0.051898856, -0.07163099, 0.023290059, -0.05910354, 0.035753418, -0.12370726, 0.00086394034, 0.062437817, 0.009168275, 0.003083251, 0.034232344, -0.02869723, -0.013457852, -0.011179466, 0.013072467, -0.003246991, -0.0380963, 0.027967058, -0.075501956, 0.0020709995, 0.009059259, 0.038587045, -0.00038104434, -0.0018610929, -0.009475333, -0.058327895, -0.0032828397, 0.004082257, -0.02602711, 0.014781226, -0.02390209, 0.0125596225, 0.08649576, 0.01703702, 0.03508497, 0.022272123, -0.04628153, -0.048454344, -0.0026485103, -0.03246412, 0.027184749, 0.009867273, 0.14205816, 0.0078798365, 0.02190687, -0.045301028, 0.040254034, -0.012405296, 0.02776755, -0.023437733, -0.010314621, 0.042177826, 0.031779177, -0.004419486, -0.04076263, -0.0052590473, 0.047290847, -0.03447568, -0.036947362, 0.031243473, -0.01243047, -0.007960975, -0.0105248885, 0.0032904854, -0.040179256, 0.022467114, -0.016306987, -0.014524242, 0.0072526056, -0.052280653, -0.012893598, -0.018354755, -0.039249703, 0.019507786, -0.03402438, -0.018815486, 0.037815843, 0.011572507, 0.01665657, 0.05349542, 0.06262594, -0.030739747, -0.01770206, -0.008022269, 0.044468857, 0.01187554, -0.03259911, -0.045163155, 0.005873695, -0.007031134, 0.038209956, 0.009773543, 0.018458132, 0.03298603, -0.04802215, -0.029331522, 0.009736381, 0.0014193252, -0.029266646, 0.023204679, 0.042884104, 0.036555525, 0.01989023, 0.020288104, -0.0019939796, 0.046266165, 0.009911118, -0.042073734, 0.0065396074, 0.065789275, 0.09641775, 0.017465355, 0.013128908, -0.03578239, 0.0231149, -0.021422157, -0.020437583, 0.025115158, 0.07037789, -0.0053526293, 0.0332623, -0.026476895, -0.03033616, -0.019557651, -0.03204936, 0.03887614, -0.027996426, 0.0013627007, 0.022591986, -0.049152315, -0.0028359122, -0.0057826117, 0.021139933, -0.05027323, 0.03936416, 0.04173886, -0.01125345, -0.023771996, 0.02028911, 0.0033836125, 0.031044248, 0.020033073, -0.027494857, -0.033545006, -0.058906768, 0.073347345, 0.062005993, 0.058484167, -0.00084693066, 0.005806394, 0.015744092, -0.03523072, 0.02922224, 0.0038474149, -0.0039008649, -0.015494569, -0.00070764316, -0.094965115, 0.015117273, 0.0043013617, 0.035153188, -0.061654534, 0.11085618, -0.07268279, -0.04717712, 0.032327536, -0.00704601, 0.037253235, 0.039828334, 0.00019132228, 0.028836014, -0.03307291, 0.050360598, 0.025420163, -0.015225513, -0.018811153, -0.022560537, -0.017732488, 0.020477327, 0.006707524, 0.058765963, -0.013588514, -0.020977682, 0.008896715, 0.04134574, -0.10698203, 0.004244291, -0.03720219, 0.0044170176, 0.041443963, 0.0027526275, -0.0021434748, -0.015335212, 0.0079962425, -0.02696693, -0.02288115, 0.031034293, 0.017682327, -0.05848914, -0.04479324, 0.011601903, 0.010388493, -0.017750131, -0.021489227, -0.0032729304, -0.010810562, 0.039271474, -0.005443907, -0.03595853, 0.0087571675, 0.05415203, 0.08646665, -0.013219114, 0.014869744, 0.0072967107, 0.025243847, 0.008245362, 0.018706806, -0.00870218, 0.016055388, 0.1125789, 0.007172758, -0.10118515, -0.06442794, 0.02315382, -0.06188186, -0.047224343, -0.0068433783, -0.018128177, -0.018271362, 0.02823152, 0.025293395, -0.0020494026, 0.0068809926, 0.017121902, 0.018439798, 0.03130178, -0.033437964, 0.039703637, -0.037016135, -0.037987944, 0.042977445, -0.012018748, 0.0035625743, -0.041630413, 0.017406989, -0.01154436, -0.004412928, 0.022141416, -0.0036727574, -0.008466987, 0.049739495, -0.06508093, -0.017235989, 0.02064509, 0.016321411, 0.02698845, 0.07759906, 0.017539669, -0.017168278, -0.0035778203, -0.0042685103, -0.026442358, 0.009349095, -0.029512957, -0.0065311617, -0.013559519, 0.0011971226, -0.009184269, -0.031676, -0.038088094, -0.016622547, 0.02486724, 0.032041576, -0.0055186623, 0.12189721, 0.043474462, -0.047649466, 0.027484516, -0.0035824412, -0.05383745, -0.008161388, -0.053657126, -0.0027364586, -0.00012998936, -0.022307076, -0.0486638, -0.028614787, -0.02132962, 0.0058860867, -0.06802224, 0.02570573, -0.034879185, 0.015381588, -0.047763627, -0.0032830043, -0.0015959376, -0.029630827, 0.038304392, -0.032076925, 0.021378756, -0.00052743126, -0.022812814, -0.025454491, -0.0023286757, 0.02404244, -0.0006882598, 0.0044533503, -0.0035739143, -0.06078285, -0.024933875, 0.030997192, 0.059662618, -0.054907784, 0.009324956, -0.007146112, 0.00516383, 0.030976022, -0.00035195865, -0.07011518, 0.06669572, -0.016511286, 0.031048367, 0.016499205, -0.02108085, -0.0045708157, -0.008500429, -0.25783044, 0.041272227, -0.0057234215, 0.016666386, 0.06816838, -0.009868127, 0.014825844, -0.022925615, -0.008001345, 0.046653997, -0.00014183977, -0.0026383696, -0.03135771, -0.030197483, 0.03716319, 0.0051222467, 0.033846315, -0.039608024, -0.029459938, 0.014192158, 0.015020755, -0.059405386, 0.044410657, 0.0031503357, -0.030107027, -0.032072756, -0.014434276, 0.017240832, 0.012384157, 0.027699955, 0.015897155, -0.017908351, 0.044406805, -0.06329205, 0.035939753, 0.024845755, 0.03015499, -0.0450442, -0.030212563, -0.04875517, -0.02823563, 0.05420893, 0.031548176, -0.0060583507, -0.017916419, -0.04930094, 0.020581705, -0.020350741, -0.020912305, -0.026117438, -0.04963092, -0.025120517, 0.002230628, 0.011512409, -0.023473363, -0.04301427, 0.018177832, 0.010988586, 0.027035486, 0.043955598, 0.019385587, -0.039110214, 0.07951547, 0.03305704, -0.022609217, -0.033687174, -0.032354735, -0.025954131, -0.01293125, 0.019692834, 0.00054087455, -0.03605654, 0.018381594, 0.0050960053, 0.011778557, 0.054119013, -0.018572157, 0.020884385, -0.030553969, 0.0099051595, 0.008738324, 0.03167156, -0.019423256, -0.025590187]
client.search(
    collection_name="wolt_food",
    query_vector=( search_vec),
    limit=3,
    query_filter=models.Filter(
    must=[
        models.FieldCondition(
    key="cafe.location",
        geo_radius=models.GeoRadius(
        center=models.GeoPoint(
            lon=33.36,
            lat=35.16,
        ),
        radius=10000.0,
    ),)]))
# Out:
# [ScoredPoint(id=434149, version=20359, score=0.7987976, payload={'cafe': {'address': 'Tseriou 109', 'categories': ['healthy'], 'location': {'lat': 35.131154, 'lon': 33.3390252}, 'menu_id': '60586e334df11042f0349803', 'name': 'Etherio Tseriou', 'rating': 9.6, 'slug': 'etherio-tseriou'}, 'description': 'Yogurt, desserts\n1 pc(s), 1.15 EUR /pc', 'image': 'https://wolt-menu-images-cdn.wolt.com/menu-images/60544797dd99410763c552fc/5e1dd7ba-8af2-11eb-8c2c-8af53a96fe4d_wolt_aitherio_612.jpeg', 'image_file': '5e1dd7ba-8af2-11eb-8c2c-8af53a96fe4d_wolt_aitherio_612.jpeg', 'name': 'Charalambides Christis Strained Goat Yogurt 100g Bio'}, vector=None, shard_key=None),
# ...

# %%
# Search with filters - filtering conditions - Geo Multi polygon

search_vec = [-0.027882958, 0.044092737, 0.0731473, 0.06553474, 0.024171988, 0.01697372, 0.0020604038, 0.018047482, -0.031200834, -0.014620315, -0.03596877, -0.008047461, 0.020798953, -0.014641951, 0.012549569, -0.029867202, 0.017640492, 0.020679252, 0.014639293, 0.02098035, -0.11850266, 0.008514167, -0.009126163, -0.03365829, -0.050205294, 0.017878275, -0.013079402, -0.03470298, 0.0053403503, -0.030538736, -0.00077569514, 0.046366554, 0.021818455, 0.048005834, 0.04522572, 0.013886643, -0.040764034, -0.019520732, -0.028808843, 0.07130225, -0.040791865, -0.010126803, -0.018052312, -0.002201882, -0.02058981, 0.03004692, -0.015570573, -0.00031868406, -0.0065039033, -0.045852456, 0.037677098, -0.007673897, 0.041015055, -0.0016164425, 0.008414605, 0.004175664, -0.050539035, -0.006734321, 0.08072506, -0.02726352, 0.03412241, -0.013328949, 0.0043830182, -0.020793792, -0.053872947, 0.012582162, 0.025352875, 0.05972377, -0.047683716, -0.040093377, -0.055419512, -0.0015524544, -0.06110616, 0.00039961239, 0.017122721, 0.011367437, 0.011612826, 0.017466443, 0.03495627, 0.037525106, 0.03702163, 0.029719371, 0.022293076, -0.103361145, -0.0051242076, -0.024882244, -0.0020247647, -0.034090083, -0.011648688, -0.0196668, 0.030498808, 0.049275327, -0.54135513, -0.0009911052, 0.05663518, 0.07849116, -0.026038505, -0.0178324, -0.035706922, -0.011421131, 0.0029203151, -0.051898856, -0.07163099, 0.023290059, -0.05910354, 0.035753418, -0.12370726, 0.00086394034, 0.062437817, 0.009168275, 0.003083251, 0.034232344, -0.02869723, -0.013457852, -0.011179466, 0.013072467, -0.003246991, -0.0380963, 0.027967058, -0.075501956, 0.0020709995, 0.009059259, 0.038587045, -0.00038104434, -0.0018610929, -0.009475333, -0.058327895, -0.0032828397, 0.004082257, -0.02602711, 0.014781226, -0.02390209, 0.0125596225, 0.08649576, 0.01703702, 0.03508497, 0.022272123, -0.04628153, -0.048454344, -0.0026485103, -0.03246412, 0.027184749, 0.009867273, 0.14205816, 0.0078798365, 0.02190687, -0.045301028, 0.040254034, -0.012405296, 0.02776755, -0.023437733, -0.010314621, 0.042177826, 0.031779177, -0.004419486, -0.04076263, -0.0052590473, 0.047290847, -0.03447568, -0.036947362, 0.031243473, -0.01243047, -0.007960975, -0.0105248885, 0.0032904854, -0.040179256, 0.022467114, -0.016306987, -0.014524242, 0.0072526056, -0.052280653, -0.012893598, -0.018354755, -0.039249703, 0.019507786, -0.03402438, -0.018815486, 0.037815843, 0.011572507, 0.01665657, 0.05349542, 0.06262594, -0.030739747, -0.01770206, -0.008022269, 0.044468857, 0.01187554, -0.03259911, -0.045163155, 0.005873695, -0.007031134, 0.038209956, 0.009773543, 0.018458132, 0.03298603, -0.04802215, -0.029331522, 0.009736381, 0.0014193252, -0.029266646, 0.023204679, 0.042884104, 0.036555525, 0.01989023, 0.020288104, -0.0019939796, 0.046266165, 0.009911118, -0.042073734, 0.0065396074, 0.065789275, 0.09641775, 0.017465355, 0.013128908, -0.03578239, 0.0231149, -0.021422157, -0.020437583, 0.025115158, 0.07037789, -0.0053526293, 0.0332623, -0.026476895, -0.03033616, -0.019557651, -0.03204936, 0.03887614, -0.027996426, 0.0013627007, 0.022591986, -0.049152315, -0.0028359122, -0.0057826117, 0.021139933, -0.05027323, 0.03936416, 0.04173886, -0.01125345, -0.023771996, 0.02028911, 0.0033836125, 0.031044248, 0.020033073, -0.027494857, -0.033545006, -0.058906768, 0.073347345, 0.062005993, 0.058484167, -0.00084693066, 0.005806394, 0.015744092, -0.03523072, 0.02922224, 0.0038474149, -0.0039008649, -0.015494569, -0.00070764316, -0.094965115, 0.015117273, 0.0043013617, 0.035153188, -0.061654534, 0.11085618, -0.07268279, -0.04717712, 0.032327536, -0.00704601, 0.037253235, 0.039828334, 0.00019132228, 0.028836014, -0.03307291, 0.050360598, 0.025420163, -0.015225513, -0.018811153, -0.022560537, -0.017732488, 0.020477327, 0.006707524, 0.058765963, -0.013588514, -0.020977682, 0.008896715, 0.04134574, -0.10698203, 0.004244291, -0.03720219, 0.0044170176, 0.041443963, 0.0027526275, -0.0021434748, -0.015335212, 0.0079962425, -0.02696693, -0.02288115, 0.031034293, 0.017682327, -0.05848914, -0.04479324, 0.011601903, 0.010388493, -0.017750131, -0.021489227, -0.0032729304, -0.010810562, 0.039271474, -0.005443907, -0.03595853, 0.0087571675, 0.05415203, 0.08646665, -0.013219114, 0.014869744, 0.0072967107, 0.025243847, 0.008245362, 0.018706806, -0.00870218, 0.016055388, 0.1125789, 0.007172758, -0.10118515, -0.06442794, 0.02315382, -0.06188186, -0.047224343, -0.0068433783, -0.018128177, -0.018271362, 0.02823152, 0.025293395, -0.0020494026, 0.0068809926, 0.017121902, 0.018439798, 0.03130178, -0.033437964, 0.039703637, -0.037016135, -0.037987944, 0.042977445, -0.012018748, 0.0035625743, -0.041630413, 0.017406989, -0.01154436, -0.004412928, 0.022141416, -0.0036727574, -0.008466987, 0.049739495, -0.06508093, -0.017235989, 0.02064509, 0.016321411, 0.02698845, 0.07759906, 0.017539669, -0.017168278, -0.0035778203, -0.0042685103, -0.026442358, 0.009349095, -0.029512957, -0.0065311617, -0.013559519, 0.0011971226, -0.009184269, -0.031676, -0.038088094, -0.016622547, 0.02486724, 0.032041576, -0.0055186623, 0.12189721, 0.043474462, -0.047649466, 0.027484516, -0.0035824412, -0.05383745, -0.008161388, -0.053657126, -0.0027364586, -0.00012998936, -0.022307076, -0.0486638, -0.028614787, -0.02132962, 0.0058860867, -0.06802224, 0.02570573, -0.034879185, 0.015381588, -0.047763627, -0.0032830043, -0.0015959376, -0.029630827, 0.038304392, -0.032076925, 0.021378756, -0.00052743126, -0.022812814, -0.025454491, -0.0023286757, 0.02404244, -0.0006882598, 0.0044533503, -0.0035739143, -0.06078285, -0.024933875, 0.030997192, 0.059662618, -0.054907784, 0.009324956, -0.007146112, 0.00516383, 0.030976022, -0.00035195865, -0.07011518, 0.06669572, -0.016511286, 0.031048367, 0.016499205, -0.02108085, -0.0045708157, -0.008500429, -0.25783044, 0.041272227, -0.0057234215, 0.016666386, 0.06816838, -0.009868127, 0.014825844, -0.022925615, -0.008001345, 0.046653997, -0.00014183977, -0.0026383696, -0.03135771, -0.030197483, 0.03716319, 0.0051222467, 0.033846315, -0.039608024, -0.029459938, 0.014192158, 0.015020755, -0.059405386, 0.044410657, 0.0031503357, -0.030107027, -0.032072756, -0.014434276, 0.017240832, 0.012384157, 0.027699955, 0.015897155, -0.017908351, 0.044406805, -0.06329205, 0.035939753, 0.024845755, 0.03015499, -0.0450442, -0.030212563, -0.04875517, -0.02823563, 0.05420893, 0.031548176, -0.0060583507, -0.017916419, -0.04930094, 0.020581705, -0.020350741, -0.020912305, -0.026117438, -0.04963092, -0.025120517, 0.002230628, 0.011512409, -0.023473363, -0.04301427, 0.018177832, 0.010988586, 0.027035486, 0.043955598, 0.019385587, -0.039110214, 0.07951547, 0.03305704, -0.022609217, -0.033687174, -0.032354735, -0.025954131, -0.01293125, 0.019692834, 0.00054087455, -0.03605654, 0.018381594, 0.0050960053, 0.011778557, 0.054119013, -0.018572157, 0.020884385, -0.030553969, 0.0099051595, 0.008738324, 0.03167156, -0.019423256, -0.025590187]
client.search(
    collection_name="wolt_food",
    query_vector=( search_vec),
    limit=3,
    query_filter=models.Filter(
    must=[
        models.FieldCondition(
    key="cafe.location",
         geo_polygon=models.GeoPolygon(
        exterior=models.GeoLineString(
            points=[
                models.GeoPoint(
                    lon=-70.0,
                    lat=-70.0,
                ),
                models.GeoPoint(
                    lon=60.0,
                    lat=-70.0,
                ),
                models.GeoPoint(
                    lon=60.0,
                    lat=60.0,
                ),
                models.GeoPoint(
                    lon=-70.0,
                    lat=60.0,
                ),
                models.GeoPoint(
                    lon=-70.0,
                    lat=-70.0,
                ),
            ]
        ),
        )
        )
        ]
    )
)
# Out:
# [ScoredPoint(id=1451234, version=68032, score=1.0183411, payload={'cafe': {'address': 'Skt. Pauls Kirkeplads 19 st tv', 'categories': ['pizza', 'italian'], 'location': {'lat': 56.14561089999999, 'lon': 10.2045166}, 'menu_id': '60a62b0d52d7b5c7d527562b', 'name': 'Amigo Pizza og Grill', 'rating': 8.2, 'slug': 'amigo-pizza-og-grill'}, 'description': '', 'image': 'https://wolt-menu-images-cdn.wolt.com/menu-images/60a62b0d52d7b5c7d527562b/26445192-ff5b-11eb-bcc9-0ae0c111c25d_wolt_21.08.12_amigo_pizza1209.jpeg', 'image_file': '26445192-ff5b-11eb-bcc9-0ae0c111c25d_wolt_21.08.12_amigo_pizza1209.jpeg', 'name': 'Ayran'}, vector=None, shard_key=None),
# ...

# %%
# Search with filters - filtering conditions - Is Empty

search_vec = [-0.027882958, 0.044092737, 0.0731473, 0.06553474, 0.024171988, 0.01697372, 0.0020604038, 0.018047482, -0.031200834, -0.014620315, -0.03596877, -0.008047461, 0.020798953, -0.014641951, 0.012549569, -0.029867202, 0.017640492, 0.020679252, 0.014639293, 0.02098035, -0.11850266, 0.008514167, -0.009126163, -0.03365829, -0.050205294, 0.017878275, -0.013079402, -0.03470298, 0.0053403503, -0.030538736, -0.00077569514, 0.046366554, 0.021818455, 0.048005834, 0.04522572, 0.013886643, -0.040764034, -0.019520732, -0.028808843, 0.07130225, -0.040791865, -0.010126803, -0.018052312, -0.002201882, -0.02058981, 0.03004692, -0.015570573, -0.00031868406, -0.0065039033, -0.045852456, 0.037677098, -0.007673897, 0.041015055, -0.0016164425, 0.008414605, 0.004175664, -0.050539035, -0.006734321, 0.08072506, -0.02726352, 0.03412241, -0.013328949, 0.0043830182, -0.020793792, -0.053872947, 0.012582162, 0.025352875, 0.05972377, -0.047683716, -0.040093377, -0.055419512, -0.0015524544, -0.06110616, 0.00039961239, 0.017122721, 0.011367437, 0.011612826, 0.017466443, 0.03495627, 0.037525106, 0.03702163, 0.029719371, 0.022293076, -0.103361145, -0.0051242076, -0.024882244, -0.0020247647, -0.034090083, -0.011648688, -0.0196668, 0.030498808, 0.049275327, -0.54135513, -0.0009911052, 0.05663518, 0.07849116, -0.026038505, -0.0178324, -0.035706922, -0.011421131, 0.0029203151, -0.051898856, -0.07163099, 0.023290059, -0.05910354, 0.035753418, -0.12370726, 0.00086394034, 0.062437817, 0.009168275, 0.003083251, 0.034232344, -0.02869723, -0.013457852, -0.011179466, 0.013072467, -0.003246991, -0.0380963, 0.027967058, -0.075501956, 0.0020709995, 0.009059259, 0.038587045, -0.00038104434, -0.0018610929, -0.009475333, -0.058327895, -0.0032828397, 0.004082257, -0.02602711, 0.014781226, -0.02390209, 0.0125596225, 0.08649576, 0.01703702, 0.03508497, 0.022272123, -0.04628153, -0.048454344, -0.0026485103, -0.03246412, 0.027184749, 0.009867273, 0.14205816, 0.0078798365, 0.02190687, -0.045301028, 0.040254034, -0.012405296, 0.02776755, -0.023437733, -0.010314621, 0.042177826, 0.031779177, -0.004419486, -0.04076263, -0.0052590473, 0.047290847, -0.03447568, -0.036947362, 0.031243473, -0.01243047, -0.007960975, -0.0105248885, 0.0032904854, -0.040179256, 0.022467114, -0.016306987, -0.014524242, 0.0072526056, -0.052280653, -0.012893598, -0.018354755, -0.039249703, 0.019507786, -0.03402438, -0.018815486, 0.037815843, 0.011572507, 0.01665657, 0.05349542, 0.06262594, -0.030739747, -0.01770206, -0.008022269, 0.044468857, 0.01187554, -0.03259911, -0.045163155, 0.005873695, -0.007031134, 0.038209956, 0.009773543, 0.018458132, 0.03298603, -0.04802215, -0.029331522, 0.009736381, 0.0014193252, -0.029266646, 0.023204679, 0.042884104, 0.036555525, 0.01989023, 0.020288104, -0.0019939796, 0.046266165, 0.009911118, -0.042073734, 0.0065396074, 0.065789275, 0.09641775, 0.017465355, 0.013128908, -0.03578239, 0.0231149, -0.021422157, -0.020437583, 0.025115158, 0.07037789, -0.0053526293, 0.0332623, -0.026476895, -0.03033616, -0.019557651, -0.03204936, 0.03887614, -0.027996426, 0.0013627007, 0.022591986, -0.049152315, -0.0028359122, -0.0057826117, 0.021139933, -0.05027323, 0.03936416, 0.04173886, -0.01125345, -0.023771996, 0.02028911, 0.0033836125, 0.031044248, 0.020033073, -0.027494857, -0.033545006, -0.058906768, 0.073347345, 0.062005993, 0.058484167, -0.00084693066, 0.005806394, 0.015744092, -0.03523072, 0.02922224, 0.0038474149, -0.0039008649, -0.015494569, -0.00070764316, -0.094965115, 0.015117273, 0.0043013617, 0.035153188, -0.061654534, 0.11085618, -0.07268279, -0.04717712, 0.032327536, -0.00704601, 0.037253235, 0.039828334, 0.00019132228, 0.028836014, -0.03307291, 0.050360598, 0.025420163, -0.015225513, -0.018811153, -0.022560537, -0.017732488, 0.020477327, 0.006707524, 0.058765963, -0.013588514, -0.020977682, 0.008896715, 0.04134574, -0.10698203, 0.004244291, -0.03720219, 0.0044170176, 0.041443963, 0.0027526275, -0.0021434748, -0.015335212, 0.0079962425, -0.02696693, -0.02288115, 0.031034293, 0.017682327, -0.05848914, -0.04479324, 0.011601903, 0.010388493, -0.017750131, -0.021489227, -0.0032729304, -0.010810562, 0.039271474, -0.005443907, -0.03595853, 0.0087571675, 0.05415203, 0.08646665, -0.013219114, 0.014869744, 0.0072967107, 0.025243847, 0.008245362, 0.018706806, -0.00870218, 0.016055388, 0.1125789, 0.007172758, -0.10118515, -0.06442794, 0.02315382, -0.06188186, -0.047224343, -0.0068433783, -0.018128177, -0.018271362, 0.02823152, 0.025293395, -0.0020494026, 0.0068809926, 0.017121902, 0.018439798, 0.03130178, -0.033437964, 0.039703637, -0.037016135, -0.037987944, 0.042977445, -0.012018748, 0.0035625743, -0.041630413, 0.017406989, -0.01154436, -0.004412928, 0.022141416, -0.0036727574, -0.008466987, 0.049739495, -0.06508093, -0.017235989, 0.02064509, 0.016321411, 0.02698845, 0.07759906, 0.017539669, -0.017168278, -0.0035778203, -0.0042685103, -0.026442358, 0.009349095, -0.029512957, -0.0065311617, -0.013559519, 0.0011971226, -0.009184269, -0.031676, -0.038088094, -0.016622547, 0.02486724, 0.032041576, -0.0055186623, 0.12189721, 0.043474462, -0.047649466, 0.027484516, -0.0035824412, -0.05383745, -0.008161388, -0.053657126, -0.0027364586, -0.00012998936, -0.022307076, -0.0486638, -0.028614787, -0.02132962, 0.0058860867, -0.06802224, 0.02570573, -0.034879185, 0.015381588, -0.047763627, -0.0032830043, -0.0015959376, -0.029630827, 0.038304392, -0.032076925, 0.021378756, -0.00052743126, -0.022812814, -0.025454491, -0.0023286757, 0.02404244, -0.0006882598, 0.0044533503, -0.0035739143, -0.06078285, -0.024933875, 0.030997192, 0.059662618, -0.054907784, 0.009324956, -0.007146112, 0.00516383, 0.030976022, -0.00035195865, -0.07011518, 0.06669572, -0.016511286, 0.031048367, 0.016499205, -0.02108085, -0.0045708157, -0.008500429, -0.25783044, 0.041272227, -0.0057234215, 0.016666386, 0.06816838, -0.009868127, 0.014825844, -0.022925615, -0.008001345, 0.046653997, -0.00014183977, -0.0026383696, -0.03135771, -0.030197483, 0.03716319, 0.0051222467, 0.033846315, -0.039608024, -0.029459938, 0.014192158, 0.015020755, -0.059405386, 0.044410657, 0.0031503357, -0.030107027, -0.032072756, -0.014434276, 0.017240832, 0.012384157, 0.027699955, 0.015897155, -0.017908351, 0.044406805, -0.06329205, 0.035939753, 0.024845755, 0.03015499, -0.0450442, -0.030212563, -0.04875517, -0.02823563, 0.05420893, 0.031548176, -0.0060583507, -0.017916419, -0.04930094, 0.020581705, -0.020350741, -0.020912305, -0.026117438, -0.04963092, -0.025120517, 0.002230628, 0.011512409, -0.023473363, -0.04301427, 0.018177832, 0.010988586, 0.027035486, 0.043955598, 0.019385587, -0.039110214, 0.07951547, 0.03305704, -0.022609217, -0.033687174, -0.032354735, -0.025954131, -0.01293125, 0.019692834, 0.00054087455, -0.03605654, 0.018381594, 0.0050960053, 0.011778557, 0.054119013, -0.018572157, 0.020884385, -0.030553969, 0.0099051595, 0.008738324, 0.03167156, -0.019423256, -0.025590187]
client.search(
    collection_name="wolt_food",
    query_vector=( search_vec),
    limit=3,
    query_filter=models.Filter(
    must=
0.02570573, -0.034879185, 0.015381588, -0.047763627, -0.0032830043, -0.0015959376, -0.029630827, 0.038304392, -0.032076925, 0.021378756, -0.00052743126, -0.022812814, -0.025454491, -0.0023286757, 0.02404244, -0.0006882598, 0.0044533503, -0.0035739143, -0.06078285, -0.024933875, 0.030997192, 0.059662618, -0.054907784, 0.009324956, -0.007146112, 0.00516383, 0.030976022, -0.00035195865, -0.07011518, 0.06669572, -0.016511286, 0.031048367, 0.016499205, -0.02108085, -0.0045708157, -0.008500429, -0.25783044, 0.041272227, -0.0057234215, 0.016666386, 0.06816838, -0.009868127, 0.014825844, -0.022925615, -0.008001345, 0.046653997, -0.00014183977, -0.0026383696, -0.03135771, -0.030197483, 0.03716319, 0.0051222467, 0.033846315, -0.039608024, -0.029459938, 0.014192158, 0.015020755, -0.059405386, 0.044410657, 0.0031503357, -0.030107027, -0.032072756, -0.014434276, 0.017240832, 0.012384157, 0.027699955, 0.015897155, -0.017908351, 0.044406805, -0.06329205, 0.035939753, 0.024845755, 0.03015499, -0.0450442, -0.030212563, -0.04875517, -0.02823563, 0.05420893, 0.031548176, -0.0060583507, -0.017916419, -0.04930094, 0.020581705, -0.020350741, -0.020912305, -0.026117438, -0.04963092, -0.025120517, 0.002230628, 0.011512409, -0.023473363, -0.04301427, 0.018177832, 0.010988586, 0.027035486, 0.043955598, 0.019385587, -0.039110214, 0.07951547, 0.03305704, -0.022609217, -0.033687174, -0.032354735, -0.025954131, -0.01293125, 0.019692834, 0.00054087455, -0.03605654, 0.018381594, 0.0050960053, 0.011778557, 0.054119013, -0.018572157, 0.020884385, -0.030553969, 0.0099051595, 0.008738324, 0.03167156, -0.019423256, -0.025590187]
client.search(
    collection_name="wolt_food",
    query_vector=( search_vec),
    limit=3,
    query_filter=models.Filter(
    must=[            models.HasIdCondition(has_id=[1, 2,3])
],
))
# Out:
# [ScoredPoint(id=3, version=6, score=0.5422058, payload={'cafe': {'address': 'Fjordgata 17B', 'categories': ['bakery', 'bakeries', 'breakfast', 'brunch', 'cafe', 'coffee-tea', 'dessert', 'healthy', 'smoothie', 'sweets', 'vegan', 'vegetarian'], 'location': {'lat': 63.4344428, 'lon': 10.4006097}, 'menu_id': '621ca6ffaf57b97173edd98e', 'name': 'Sweet Spot', 'rating': 8.8, 'slug': 'sweet-spot'}, 'description': 'En smooth og næringsrik smoothiebowl med smak av Skogsbær. \nToppes med jordbær, kiwi, banan, kokosflak, chiafrø og granola.\nSjokoladesaus på toppen. \n\nVi har også glutenfri Bare Bra Granola om man vil ha glutenfrit alternativ, men skriv dette i kommentarfeltet. \n\n350 Kcal og 23 g protein\nSelve bowlen er vegansk. \nHUSK å si ifra om du vil ha glutenfri granola.', 'image': 'https://wolt-menu-images-cdn.wolt.com/menu-images/621ca6ffaf57b97173edd98e/1c4a5920-ee70-11ec-9325-1a65475397d2_tempimageyslqtw.jpeg', 'image_file': '1c4a5920-ee70-11ec-9325-1a65475397d2_tempimageyslqtw.jpe
# ...
